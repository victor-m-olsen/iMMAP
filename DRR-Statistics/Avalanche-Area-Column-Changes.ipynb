# %%
import json
import geopandas as gpd
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# Load database configuration from file
with open(r'D:\iMMAP\code\db_config\hsdc_local_db_config.json', 'r') as f:
    config = json.load(f)

# Create database URL with credentials
db_url = f"postgresql://{config['username']}:{config['password']}@{config['host']}:{config['port']}/{config['database']}"

# Connect to the database
con = create_engine(db_url)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Convert from m2 to km2

# %%
# Replace m2 with km2
adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_adm1_av_stats', con)
adm['km2'] = adm['m2'] / 1000000
adm = adm.drop(columns=['m2'])
adm.to_postgis('SELECT * from afg_admbnda_adm1_av_stats', con, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'm2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 3>()
#       1 # Replace m2 with km2
#       2 adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_adm1_av_stats', con)
# ----> 3 adm['km2'] = adm['m2'] / 1000000
#       4 adm = adm.drop(columns=['m2'])
#       5 adm.to_postgis('SELECT * from afg_admbnda_adm1_av_stats', con, if_exists='replace')
#
# File ~\anaconda3\envs\earth2\lib\site-packages\geopandas\geodataframe.py:1415, in GeoDataFrame.__getitem__(self, key)
#    1409 def __getitem__(self, key):
#    1410     """
#    1411     If the result is a column containing only 'geometry', return a
#    1412     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1413     return a GeoDataFrame.
#    1414     """
# -> 1415     result = super().__getitem__(key)
#    1416     geo_col = self._geometry_column_name
#    1417     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'm2'

# %%
# Replace m2 with km2
adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_adm2_av_stats', con)
adm['km2'] = adm['m2'] / 1000000
adm = adm.drop(columns=['m2'])
adm.to_postgis('SELECT * from afg_admbnda_adm2_av_stats', con, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'm2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 3>()
#       1 # Replace m2 with km2
#       2 adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_adm2_av_stats', con)
# ----> 3 adm['km2'] = adm['m2'] / 1000000
#       4 adm = adm.drop(columns=['m2'])
#       5 adm.to_postgis('SELECT * from afg_admbnda_adm2_av_stats', con, if_exists='replace')
#
# File ~\anaconda3\envs\earth2\lib\site-packages\geopandas\geodataframe.py:1415, in GeoDataFrame.__getitem__(self, key)
#    1409 def __getitem__(self, key):
#    1410     """
#    1411     If the result is a column containing only 'geometry', return a
#    1412     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1413     return a GeoDataFrame.
#    1414     """
# -> 1415     result = super().__getitem__(key)
#    1416     geo_col = self._geometry_column_name
#    1417     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'm2'

# %%
# Replace m2 with km2
adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_region_av_stats', con)
adm['km2'] = adm['m2'] / 1000000
adm = adm.drop(columns=['m2'])
adm.to_postgis('SELECT * from afg_admbnda_region_av_stats', con, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'm2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 3>()
#       1 # Replace m2 with km2
#       2 adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_region_av_stats', con)
# ----> 3 adm['km2'] = adm['m2'] / 1000000
#       4 adm = adm.drop(columns=['m2'])
#       5 adm.to_postgis('SELECT * from afg_admbnda_region_av_stats', con, if_exists='replace')
#
# File ~\anaconda3\envs\earth2\lib\site-packages\geopandas\geodataframe.py:1415, in GeoDataFrame.__getitem__(self, key)
#    1409 def __getitem__(self, key):
#    1410     """
#    1411     If the result is a column containing only 'geometry', return a
#    1412     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1413     return a GeoDataFrame.
#    1414     """
# -> 1415     result = super().__getitem__(key)
#    1416     geo_col = self._geometry_column_name
#    1417     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\earth2\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'm2'

# %% [markdown]
# ### Compare across admin levels

# %%
adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_adm2_av_stats', con)
print('build_count     ', adm.build.sum())
print('pop_sum         ', adm.pop_sum.sum())
print('km2             ', adm.km2.sum())
# Out:
# build_count      128866.0
# pop_sum          1327956.5593264997
# km2              33752.20542041327

# %%
adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_adm2_av_stats', con)
print('build_count     ', adm.build.sum())
print('pop_sum         ', adm.pop_sum.sum())
print('km2             ', adm.km2.sum())
# Out:
# build_count      128866.0
# pop_sum          1327956.5593264997
# km2              33752.20542041327

# %%
adm = gpd.GeoDataFrame.from_postgis('SELECT * from afg_admbnda_region_av_stats', con)
print('build_count     ', adm.build.sum())
print('pop_sum         ', adm.pop_sum.sum())
print('km2             ', adm.km2.sum())
# Out:
# build_count      128866
# pop_sum          1327956.7734375
# km2              33752.205420413135

# %%
zonal_stats = gpd.read_file("D:\iMMAP\proj\ASDC\data\Avalanche-QA\subset_zonalstats_v06.shp")

# %%
zonal_stats['_sum'].sum()
# Out:
# 11384.583295929046

# %%
zonal_stats['area'].sum()
# Out:
# 240861330
