# %%
### Script for adding flood statistics (buildings, people and km2) to admin polygons

##Steps:
#dissolve flood data by district and province
#cut by new district and province
#calculate area
#zonal stats on buildings centroids
#zonal stats on population
#joining stats back to admin areas
#save to db

#Estimated run time: 48h

# %%
import os
import json
import geopandas as gpd
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 # required for exporting to postgis
import rioxarray as rxr
from rasterio.crs import CRS
from sqlalchemy import create_engine
import rasterstats
from shapely.ops import transform
from datetime import datetime

# %% [markdown]
# ### Setting connection and parameters

# %%
# Load database configuration from file
with open(r'D:\iMMAP\code\db_config\hsdc_local_db_config.json', 'r') as f:
    config = json.load(f)

# Create database URL with credentials
db_url = f"postgresql://{config['username']}:{config['password']}@{config['host']}:{config['port']}/{config['database']}"

# Connect to the database
con = create_engine(db_url)

# %%
pd.set_option('display.max_columns', None)

# %%
# Define projection
repro_crs = '+proj=cea'

# %% [markdown]
# ### Defining functions

# %%
# Clipping admin and flood zones
def clip(adm, flood):
    flood = adm.clip(flood)
    return flood

# %%
# Extracting area
def area(flood, flood_level_code):
    col_name = 'km2_{}'.format(flood_level_code)
    flood[col_name] = flood['geom'].area.div(1000000)
    return flood

# %%
# Extracting buildings
def buildings(flood, build_centroids, group_by_parameter):
     
    build_count_column = 'build_{}'.format(flood_code_list[flood_level])
    
    
    # Join building centroids to flood polygons
    print('    Joining buildings to flood polygons   Start: {}'.format(datetime.now().strftime("%H:%M:%S")))
    joined_df = gpd.sjoin(
        build_centroids,
        flood,
        how='inner',
        predicate='intersects'
    )
    print('    Joining buildings to flood polygons   End:   {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    
    # Count number of buildings within admin polygons
    print('    Counting number of buildings          Start: {}'.format(datetime.now().strftime("%H:%M:%S")))
    build_count = joined_df.groupby(
        [group_by_parameter],
        as_index=False,
    )['geom'].count() # vuid is arbitrary, we just count the row
    print('    Counting number of buildings          End:   {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    # Change column name to build_count
    build_count.rename(columns = {'geom': build_count_column}, inplace = True)
 
    # Merge build count back on to admin dataset
    flood = flood.merge(
        build_count, 
        on=group_by_parameter, 
        how='left')
    
    return flood

# %%
# Extracting population
def ZonalStats(shape_gdf, raster, stats):

    zonalSt = rasterstats.zonal_stats(shape_gdf, raster, stats = stats)
    
    df = pd.DataFrame(zonalSt)
    
    df_concat = pd.concat([df, shape_gdf], axis=1)
    
    final_gdf = gpd.GeoDataFrame(df_concat, geometry=df_concat.geom) #wkb_geometry
    
    final_gdf_ordered = final_gdf[[c for c in final_gdf if c not in [stats]] + [stats]]
    
    flood = final_gdf_ordered.rename(columns={"sum": "pop_sum_{}".format(flood_code_list[flood_level])}) #, inplace=True)
    
    flood = flood.drop(columns=['geometry'])
    
    flood = flood.set_geometry('geom')
    
    return flood

# %% [markdown]
# ### Defining reference paths and lists

# %%
pop_path = r'D:\iMMAP\data\Afghanistan\afg_worldpop_2020_UNadj_unconstrained.tif'
pop_path_cea = r'D:\iMMAP\data\Afghanistan\afg_worldpop_2020_UNadj_unconstrained_projCEA.tif'

admin_list = [
    'afg_admbnda_region',
    'afg_admbnda_adm1',
    'afg_admbnda_adm2'   
]

admin_abbreviations = [
    'region',
    'adm1',
    'adm2'
]

admin_list_groupby = [
    'reg_pcode',
    'adm1_pcode',
    'adm2_pcode'       
]

flood_list = [
    'afg_fldzonea_100k_ncia_v2_029cm_dissolve_all_v2',
    'afg_fldzonea_100k_ncia_v2_121cm_dissolve_all_v2',
    'afg_fldzonea_100k_ncia_v2_271cm_dissolve_all_v2'
]

flood_code_list = [
    '029cm',
    '121cm',
    '271cm'
]

# %% [markdown]
# ### Running functions

# %%
print("Loading buildings. Starting: ", datetime.now().strftime("%H:%M:%S"))
build_centroids = gpd.GeoDataFrame.from_postgis('SELECT * from afg_buildings_microsoft_centroids', con).to_crs(repro_crs) #afg_buildings_microsoft_centroids_testclip #build_testclip2
print("Loading buildings. Finished: ", datetime.now().strftime("%H:%M:%S"))
# Out:
# Loading buildings. Starting:  12:47:25
# Loading buildings. Finished:  12:50:50

# %%
print('\n\n\nALL PROCESSING START', datetime.now().strftime("%H:%M:%S"))

for admin_level in range(len(admin_list)):
    
    print('\n\n\n\nStarting admin loop nr {}: {}'.format(admin_level, admin_list[admin_level]))
    
    adm = gpd.GeoDataFrame.from_postgis('SELECT * from {}'.format(admin_list[admin_level]), con)
    
    adm = adm.to_crs(repro_crs)
    
    group_by_parameter = admin_list_groupby[admin_level]
        
    for flood_level in range(len(flood_list)):
        
        print('\n\nStarting flood loop nr {}'.format(flood_list[flood_level]))
        print("Current Time =", datetime.now().strftime("%H:%M:%S"))
        
        flood = gpd.GeoDataFrame.from_postgis('SELECT * from {}'.format(flood_list[flood_level]), con, 'wkb_geometry')
        
        print('Reprojecting - Start: {}'.format(datetime.now().strftime("%H:%M:%S")))
        flood = flood.to_crs(repro_crs) #OBS, if no flood level extent in admin area, then row dissapears from final output
        print('Reprojecting - End:   {}'.format(datetime.now().strftime("%H:%M:%S")))
       
        print('Clip - Start:         {}'.format(datetime.now().strftime("%H:%M:%S")))
        flood = clip(adm, flood) #.explode()
        print('Clip - End:           {}'.format(datetime.now().strftime("%H:%M:%S")))

        print('Area - Start:         {}'.format(datetime.now().strftime("%H:%M:%S")))
        flood = area(flood, flood_code_list[flood_level])
        print('Area - End:           {}'.format(datetime.now().strftime("%H:%M:%S")))
        
        print('Buildings - Start:    {}'.format(datetime.now().strftime("%H:%M:%S")))
        flood = buildings(flood, build_centroids, group_by_parameter)
        print('Buildings - End:      {}'.format(datetime.now().strftime("%H:%M:%S")))
        
        print('Zonalstats - Start:   {}'.format(datetime.now().strftime("%H:%M:%S")))
        flood = ZonalStats(flood, pop_path_cea, 'sum')
        print('Zonalstats - End:     {}'.format(datetime.now().strftime("%H:%M:%S")))
        
        
        
        print('Merging - Start:      {}'.format(datetime.now().strftime("%H:%M:%S")))
        # Subsetting the table to only the columns we want to join
        flood = pd.DataFrame(flood[[
                '{}'.format(group_by_parameter),
                'km2_{}'.format(flood_code_list[flood_level]),
                'pop_sum_{}'.format(flood_code_list[flood_level]),
                'build_{}'.format(flood_code_list[flood_level])]]
        )

        # Summaries across columns
        flood = flood.groupby(group_by_parameter).sum()
        
        adm = adm.merge(
            flood, 
            on=group_by_parameter, 
            how='left')
        print('Merging - End:        {}'.format(datetime.now().strftime("%H:%M:%S")))

        print(adm)

        print('Finished flood loop nr {}'.format(flood_list[flood_level]))
        print("Current Time =", datetime.now().strftime("%H:%M:%S"))
        
        # Save to postgis if all flood levels have been processed
        if flood_level == len(flood_list) - 1:
            adm = adm.to_crs('epsg:4326')
            adm.to_postgis('afg_admbnda_{}_flood_stats_fullsize_v02'.format(admin_abbreviations[admin_level]), con, if_exists='replace')
            print('\n\nFINISHED WITH  -  afg_admbnda_{}_flood_stats  - {}'
                      .format(admin_abbreviations[admin_level], datetime.now().strftime("%H:%M:%S")))
    
print('\n\n\nALL PROCESSING END', datetime.now().strftime("%H:%M:%S"))
# Out:
# ALL PROCESSING START 12:50:50
#
#
#
#
# Starting admin loop nr 0: afg_admbnda_region
#
#
# Starting flood loop nr afg_fldzonea_100k_ncia_v2_029cm_dissolve_all_v2
# Current Time = 12:50:50
# Reprojecting - Start: 12:51:17
# Reprojecting - End:   12:51:19
# Clip - Start:         12:51:19
# Clip - End:           14:33:28
# Area - Start:         14:33:28
# Area - End:           14:33:28
# Buildings - Start:    14:33:28
#     Joining buildings to flood polygons   Start: 14:33:28
#     Joining buildings to flood polygons   End:   01:10:20
#     Counting number of buildings          Start: 01:10:20
#     Counting number of buildings          End:   01:10:20
# Buildings - End:      01:10:20
# Zonalstats - Start:   01:10:20
# Zonalstats - End:     01:18:54
# Merging - Start:      01:18:54
# Merging - End:        01:18:54
#    id                                               geom            reg_en  \
# 0   1  MULTIPOLYGON (((7617702.961 3735993.537, 76174...          Northern
# 1   2  MULTIPOLYGON (((7304671.677 3483929.798, 73045...  Central Highland
# 2   3  MULTIPOLYGON (((7588786.360 3345978.293, 75886...     South Eastern
# 3   4  MULTIPOLYGON (((7523765.643 3314826.127, 75237...          Southern
# 4   5  MULTIPOLYGON (((7792666.678 3551912.629, 77925...           Eastern
# 5   6  MULTIPOLYGON (((7488668.638 3545395.217, 74884...           Capital
# 6   7  MULTIPOLYGON (((7925357.856 3733126.513, 79252...     North Eastern
# 7   8  MULTIPOLYGON (((6859234.301 3303643.897, 68575...           Western
#
#             reg_da reg_pcode reg_ref regalt1en regalt2en regalt1da regalt2da  \
# 0       سهیلی حوزه        NR    None      None      None      None      None
# 1  لوړه مرکزی حوزه        CH    None      None      None      None      None
# 2  جنوب ختیځه حوزه        SE    None      None      None      None      None
# 3       جنوبی حوزه        SR    None      None      None      None      None
# 4       ختیځه حوزه        ER    None      None      None      None      None
# 5       مرکزی حوزه        CR    None      None      None      None      None
# 6  سهیل ختیځه حوزه        NE    None      None      None      None      None
# 7     لویدیځه حوزه        WR    None      None      None      None      None
#
#        adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 5  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 6  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 7  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#    shape_leng  shape_area     km2_029cm  pop_sum_029cm  build_029cm
# 0   15.678772    7.751351   6401.161821   6.411514e+05       226165
# 1   15.035766    3.100092    857.810869   4.839781e+04        12470
# 2   15.949378    4.825809   6432.821280   6.275626e+05       148378
# 3   27.822820   17.576351  32422.423859   1.122232e+06       362885
# 4   10.390809    2.472625   1354.146253   5.705485e+05        85563
# 5   14.491308    3.054274   1739.510514   2.286357e+06       245411
# 6   27.870669    8.141572   4765.257053   6.804306e+05       169647
# 7   26.348523   15.642130  19018.181804   1.078627e+06       256281
# Finished flood loop nr afg_fldzonea_100k_ncia_v2_029cm_dissolve_all_v2
# Current Time = 01:18:55
#
#
# Starting flood loop nr afg_fldzonea_100k_ncia_v2_121cm_dissolve_all_v2
# Current Time = 01:18:55
# Reprojecting - Start: 01:19:26
# Reprojecting - End:   01:19:29
# Clip - Start:         01:19:29
# Clip - End:           02:20:26
# Area - Start:         02:20:26
# Area - End:           02:20:26
# Buildings - Start:    02:20:26
#     Joining buildings to flood polygons   Start: 02:20:26
#     Joining buildings to flood polygons   End:   16:21:25
#     Counting number of buildings          Start: 16:21:25
#     Counting number of buildings          End:   16:21:25
# Buildings - End:      16:21:25
# Zonalstats - Start:   16:21:25
# Zonalstats - End:     16:27:16
# Merging - Start:      16:27:16
# Merging - End:        16:27:16
#    id                                               geom            reg_en  \
# 0   1  MULTIPOLYGON (((7617702.961 3735993.537, 76174...          Northern
# 1   2  MULTIPOLYGON (((7304671.677 3483929.798, 73045...  Central Highland
# 2   3  MULTIPOLYGON (((7588786.360 3345978.293, 75886...     South Eastern
# 3   4  MULTIPOLYGON (((7523765.643 3314826.127, 75237...          Southern
# 4   5  MULTIPOLYGON (((7792666.678 3551912.629, 77925...           Eastern
# 5   6  MULTIPOLYGON (((7488668.638 3545395.217, 74884...           Capital
# 6   7  MULTIPOLYGON (((7925357.856 3733126.513, 79252...     North Eastern
# 7   8  MULTIPOLYGON (((6859234.301 3303643.897, 68575...           Western
#
#             reg_da reg_pcode reg_ref regalt1en regalt2en regalt1da regalt2da  \
# 0       سهیلی حوزه        NR    None      None      None      None      None
# 1  لوړه مرکزی حوزه        CH    None      None      None      None      None
# 2  جنوب ختیځه حوزه        SE    None      None      None      None      None
# 3       جنوبی حوزه        SR    None      None      None      None      None
# 4       ختیځه حوزه        ER    None      None      None      None      None
# 5       مرکزی حوزه        CR    None      None      None      None      None
# 6  سهیل ختیځه حوزه        NE    None      None      None      None      None
# 7     لویدیځه حوزه        WR    None      None      None      None      None
#
#        adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 5  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 6  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 7  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#    shape_leng  shape_area     km2_029cm  pop_sum_029cm  build_029cm  \
# 0   15.678772    7.751351   6401.161821   6.411514e+05       226165
# 1   15.035766    3.100092    857.810869   4.839781e+04        12470
# 2   15.949378    4.825809   6432.821280   6.275626e+05       148378
# 3   27.822820   17.576351  32422.423859   1.122232e+06       362885
# 4   10.390809    2.472625   1354.146253   5.705485e+05        85563
# 5   14.491308    3.054274   1739.510514   2.286357e+06       245411
# 6   27.870669    8.141572   4765.257053   6.804306e+05       169647
# 7   26.348523   15.642130  19018.181804   1.078627e+06       256281
#
#       km2_121cm  pop_sum_121cm  build_121cm
# 0   3833.592955   3.523827e+05       109747
# 1    602.577511   3.501955e+04         7939
# 2   3987.602169   3.774576e+05        73486
# 3  16703.330456   6.817935e+05       197798
# 4    887.750631   3.336445e+05        39404
# 5   1048.597876   1.570888e+06       146535
# 6   3109.974298   4.464008e+05        86610
# 7  11002.056309   6.499727e+05       132366
# Finished flood loop nr afg_fldzonea_100k_ncia_v2_121cm_dissolve_all_v2
# Current Time = 16:27:16
#
#
# Starting flood loop nr afg_fldzonea_100k_ncia_v2_271cm_dissolve_all_v2
# Current Time = 16:27:16
# Reprojecting - Start: 16:27:28
# Reprojecting - End:   16:27:29
# Clip - Start:         16:27:29
# Clip - End:           16:32:06
# Area - Start:         16:32:06
# Area - End:           16:32:06
# Buildings - Start:    16:32:06
#     Joining buildings to flood polygons   Start: 16:32:06
#     Joining buildings to flood polygons   End:   20:06:56
#     Counting number of buildings          Start: 20:06:56
#     Counting number of buildings          End:   20:06:56
# Buildings - End:      20:06:56
# Zonalstats - Start:   20:06:56
# Zonalstats - End:     20:07:40
# Merging - Start:      20:07:40
# Merging - End:        20:07:40
#    id                                               geom            reg_en  \
# 0   1  MULTIPOLYGON (((7617702.961 3735993.537, 76174...          Northern
# 1   2  MULTIPOLYGON (((7304671.677 3483929.798, 73045...  Central Highland
# 2   3  MULTIPOLYGON (((7588786.360 3345978.293, 75886...     South Eastern
# 3   4  MULTIPOLYGON (((7523765.643 3314826.127, 75237...          Southern
# 4   5  MULTIPOLYGON (((7792666.678 3551912.629, 77925...           Eastern
# 5   6  MULTIPOLYGON (((7488668.638 3545395.217, 74884...           Capital
# 6   7  MULTIPOLYGON (((7925357.856 3733126.513, 79252...     North Eastern
# 7   8  MULTIPOLYGON (((6859234.301 3303643.897, 68575...           Western
#
#             reg_da reg_pcode reg_ref regalt1en regalt2en regalt1da regalt2da  \
# 0       سهیلی حوزه        NR    None      None      None      None      None
# 1  لوړه مرکزی حوزه        CH    None      None      None      None      None
# 2  جنوب ختیځه حوزه        SE    None      None      None      None      None
# 3       جنوبی حوزه        SR    None      None      None      None      None
# 4       ختیځه حوزه        ER    None      None      None      None      None
# 5       مرکزی حوزه        CR    None      None      None      None      None
# 6  سهیل ختیځه حوزه        NE    None      None      None      None      None
# 7     لویدیځه حوزه        WR    None      None      None      None      None
#
#        adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 5  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 6  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 7  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#    shape_leng  shape_area     km2_029cm  pop_sum_029cm  build_029cm  \
# 0   15.678772    7.751351   6401.161821   6.411514e+05       226165
# 1   15.035766    3.100092    857.810869   4.839781e+04        12470
# 2   15.949378    4.825809   6432.821280   6.275626e+05       148378
# 3   27.822820   17.576351  32422.423859   1.122232e+06       362885
# 4   10.390809    2.472625   1354.146253   5.705485e+05        85563
# 5   14.491308    3.054274   1739.510514   2.286357e+06       245411
# 6   27.870669    8.141572   4765.257053   6.804306e+05       169647
# 7   26.348523   15.642130  19018.181804   1.078627e+06       256281
#
#       km2_121cm  pop_sum_121cm  build_121cm    km2_271cm  pop_sum_271cm  \
# 0   3833.592955   3.523827e+05       109747  1318.613782  123184.515625
# 1    602.577511   3.501955e+04         7939   246.778151   16340.505859
# 2   3987.602169   3.774576e+05        73486  1328.427350  129614.062500
# 3  16703.330456   6.817935e+05       197798  5295.097698  268623.000000
# 4    887.750631   3.336445e+05        39404   390.392365  172397.265625
# 5   1048.597876   1.570888e+06       146535   415.946234  795946.625000
# 6   3109.974298   4.464008e+05        86610  1227.975954  207903.015625
# 7  11002.056309   6.499727e+05       132366  3860.510701  262553.687500
#
#    build_271cm
# 0        33472
# 1         3357
# 2        15912
# 3        60643
# 4        15698
# 5        66473
# 6        28374
# 7        34453
# Finished flood loop nr afg_fldzonea_100k_ncia_v2_271cm_dissolve_all_v2
# Current Time = 20:07:40
#
#
# FINISHED WITH  -  afg_admbnda_region_flood_stats  - 20:07:41
#
#
#
#
# Starting admin loop nr 1: afg_admbnda_adm1
#
#
# Starting flood loop nr afg_fldzonea_100k_ncia_v2_029cm_dissolve_all_v2
# Current Time = 20:07:41
# Reprojecting - Start: 20:08:07
# Reprojecting - End:   20:08:09
# Clip - Start:         20:08:09
# Clip - End:           21:45:57
# Area - Start:         21:45:57
# Area - End:           21:45:57
# Buildings - Start:    21:45:57
#     Joining buildings to flood polygons   Start: 21:45:57
#     Joining buildings to flood polygons   End:   01:00:42
#     Counting number of buildings          Start: 01:00:42
#     Counting number of buildings          End:   01:00:42
# Buildings - End:      01:00:42
# Zonalstats - Start:   01:00:42
# Zonalstats - End:     01:04:34
# Merging - Start:      01:04:34
# Merging - End:        01:04:34
#     id                                               geom  shape_leng  \
# 0    1  MULTIPOLYGON (((7580084.127 3398346.617, 75801...   10.487964
# 1    2  MULTIPOLYGON (((6963422.952 3112388.252, 69613...   10.325135
# 2    3  MULTIPOLYGON (((7925673.149 3667998.587, 79256...    6.917788
# 3    4  MULTIPOLYGON (((7295527.260 3403656.802, 72954...    8.156241
# 4    5  MULTIPOLYGON (((7772198.026 3621013.781, 77721...    2.393424
# 5    6  MULTIPOLYGON (((7588786.360 3345978.293, 75886...    8.002717
# 6    7  MULTIPOLYGON (((7680281.934 3771997.683, 76800...    4.801921
# 7    8  MULTIPOLYGON (((7119055.533 3116028.044, 71187...   15.864174
# 8    9  MULTIPOLYGON (((7304671.677 3483929.798, 73045...    9.220719
# 9   10  MULTIPOLYGON (((7545685.605 3374667.513, 75457...    8.211958
# 10  11  MULTIPOLYGON (((7329046.186 3146040.303, 73288...   14.889878
# 11  12  MULTIPOLYGON (((7312110.176 3711489.346, 73122...    9.618385
# 12  13  MULTIPOLYGON (((7782848.175 3670513.090, 77828...    3.890563
# 22    1.252758         Takhar        تخار       AF18     None       None
# 23    0.384020        Laghman       لغمان       AF07     None       None
# 24    1.344434       Samangan      سمنگان       AF20     None       None
# 25    0.428761          Logar        لوگر       AF05     None       None
# 26    0.416132          Kunar      کنر ها       AF15     None       None
# 27    4.392619     Badakhshan      بدخشان       AF17     None       None
# 28    1.701746        Baghlan       بغلان       AF09     None       None
# 29    0.550813         Parwan       پروان       AF03     None       None
# 30    0.398140          Khost        خوست       AF14     None       None
# 31    6.007026          Hirat        هرات       AF32     None       None
# 32    0.721955      Nangarhar     ننگرهار       AF06     None       None
# 33    3.802547           Ghor         غور       AF23     None       None
#
#    adm1alt2en adm1alt1da adm1alt2da      adm0_en    adm0_da adm0_pcode  \
# 0        None       None       None  Afghanistan  افغانستان         AF
# 1        None       None       None  Afghanistan  افغانستان         AF
# 2        None       None       None  Afghanistan  افغانستان         AF
# 3        None       None       None  Afghanistan  افغانستان         AF
# 4        None       None       None  Afghanistan  افغانستان         AF
# 5        None       None       None  Afghanistan  افغانستان         AF
# 6        None       None       None  Afghanistan  افغانستان         AF
# 7        None       None       None  Afghanistan  افغانستان         AF
# 8        None       None       None  Afghanistan  افغانستان         AF
# 9        None       None       None  Afghanistan  افغانستان         AF
# 10       None       None       None  Afghanistan  افغانستان         AF
# 11       None       None       None  Afghanistan  افغانستان         AF
# 12       None       None       None  Afghanistan  افغانستان         AF
# 13       None       None       None  Afghanistan  افغانستان         AF
# 14       None       None       None  Afghanistan  افغانستان         AF
# 15       None       None       None  Afghanistan  افغانستان         AF
# 16       None       None       None  Afghanistan  افغانستان         AF
# 17       None       None       None  Afghanistan  افغانستان         AF
# 18       None       None       None  Afghanistan  افغانستان         AF
# 19       None       None       None  Afghanistan  افغانستان         AF
# 20       None       None       None  Afghanistan  افغانستان         AF
# 21       None       None       None  Afghanistan  افغانستان         AF
# 22       None       None       None  Afghanistan  افغانستان         AF
# 23       None       None       None  Afghanistan  افغانستان         AF
# 24       None       None       None  Afghanistan  افغانستان         AF
# 25       None       None       None  Afghanistan  افغانستان         AF
# 26       None       None       None  Afghanistan  افغانستان         AF
# 27       None       None       None  Afghanistan  افغانستان         AF
# 28       None       None       None  Afghanistan  افغانستان         AF
# 29       None       None       None  Afghanistan  افغانستان         AF
# 30       None       None       None  Afghanistan  افغانستان         AF
# 31       None       None       None  Afghanistan  افغانستان         AF
# 32       None       None       None  Afghanistan  افغانستان         AF
# 33       None       None       None  Afghanistan  افغانستان         AF
#
#           date     validon validto            reg_en           reg_da  \
# 0   2017-12-12  2021-11-17    None     South Eastern  جنوب ختیځه حوزه
# 1   2017-12-12  2021-11-17    None          Southern       جنوبی حوزه
# 2   2017-12-12  2021-11-17    None           Eastern       ختیځه حوزه
# 3   2017-12-12  2021-11-17    None          Southern       جنوبی حوزه
# 4   2017-12-12  2021-11-17    None           Capital       مرکزی حوزه
# 5   2017-12-12  2021-11-17    None     South Eastern  جنوب ختیځه حوزه
# 6   2017-12-12  2021-11-17    None     North Eastern  سهیل ختیځه حوزه
# 7   2017-12-12  2021-11-17    None          Southern       جنوبی حوزه
# 8   2017-12-12  2021-11-17    None  Central Highland  لوړه مرکزی حوزه
# 9   2017-12-12  2021-11-17    None          Southern       جنوبی حوزه
# 10  2017-12-12  2021-11-17    None          Southern       جنوبی حوزه
# 11  2017-12-12  2021-11-17    None          Northern       سهیلی حوزه
# 12  2017-12-12  2021-11-17    None           Capital       مرکزی حوزه
# 13  2017-12-12  2021-11-17    None          Northern       سهیلی حوزه
#
# 33  34  MULTIPOLYGON (((7193950.493 3476757.063, 71939...   15.387878
#
#     shape_area        adm1_en     adm1_da adm1_pcode adm1_ref adm1alt1en  \
# 0     2.085632         Ghazni        غزنی       AF11     None       None
# 1     3.794569         Nimroz      نیمروز       AF34     None       None
# 2     0.950518       Nuristan     نورستان       AF16     None       None
# 3     1.265532        Uruzgan      ارزگان       AF25     None       None
# 4     0.185458         Kapisa      کاپیسا       AF02     None       None
# 5     1.810899        Paktika      پکتیکا       AF12     None       None
# 6     0.794449         Kunduz        کندز       AF19     None       None
# 7     5.749524        Hilmand       هلمند       AF30     None       None
# 8     1.324432       Daykundi     دایکندی       AF24     None       None
# 9     1.627631          Zabul        زابل       AF26     None       None
# 10    5.139095       Kandahar      کندهار       AF27     None       None
# 11    2.081709         Faryab      فاریاب       AF29     None       None
# 12    0.371500       Panjsher      پنجشیر       AF08     None       None
# 13    1.070422        Jawzjan      جوزجان       AF28     None       None
# 14    1.775660         Bamyan      بامیان       AF10     None       None
# 15    0.460366          Kabul        کابل       AF01     None       None
# 16    1.907544        Badghis      بادغیس       AF31     None       None
# 17    3.925013          Farah        فراه       AF33     None       None
# 18    0.531138         Paktya       پکتیا       AF13     None       None
# 19    1.491713      Sar-e-Pul        سرپل       AF22     None       None
# 20    1.057376  Maidan Wardak  میدان وردک       AF04     None       None
# 21    1.763071          Balkh         بلخ       AF21     None       None
# 22    1.252758         Takhar        تخار       AF18     None       None
# 23    0.384020        Laghman       لغمان       AF07     None       None
# 24    1.344434       Samangan      سمنگان       AF20     None       None
# 25    0.428761          Logar        لوگر       AF05     None       None
# 26    0.416132          Kunar      کنر ها       AF15     None       None
# 27    4.392619     Badakhshan      بدخشان       AF17     None       None
# 28    1.701746        Baghlan       بغلان       AF09     None       None
# 29    0.550813         Parwan       پروان       AF03     None       None
# 30    0.398140          Khost        خوست       AF14     None       None
# 31    6.007026          Hirat        هرات       AF32     None       None
# 32    0.721955      Nangarhar     ننگرهار       AF06     None       None
# 33    3.802547           Ghor         غور       AF23     None       None
#
#    adm1alt2en adm1alt1da adm1alt2da      adm0_en    adm0_da adm0_pcode  \
# 0        None       None       None  Afghanistan  افغانستان         AF
# 1        None       None       None  Afghanistan  افغانستان         AF
# 2        None       None       None  Afghanistan  افغانستان         AF
# 3        None       None       None  Afghanistan  افغانستان         AF
# 4        None       None       None  Afghanistan  افغانستان         AF
# 5        None       None       None  Afghanistan  افغانستان         AF
# 6        None       None       None  Afghanistan  افغانستان         AF
# 7        None       None       None  Afghanistan  افغانستان         AF
# 8        None       None       None  Afghanistan  افغانستان         AF
# 9        None       None       None  Afghanistan  افغانستان         AF
# 10       None       None       None  Afghanistan  افغانستان         AF
# 11       None       None       None  Afghanistan  افغانستان         AF
# 12       None       None       None  Afghanistan  افغانستان         AF
# 13       None       None       None  Afghanistan  افغانستان         AF
# 14       None       None       None  Afghanistan  افغانستان         AF
# 15       None       None       None  Afghanistan  افغانستان         AF
# 16       None       None       None  Afghanistan  افغانستان         AF
# 0     2.085632         Ghazni        غزنی       AF11     None       None
# 1     3.794569         Nimroz      نیمروز       AF34     None       None
# 2     0.950518       Nuristan     نورستان       AF16     None       None
# 3     1.265532        Uruzgan      ارزگان       AF25     None       None
# 4     0.185458         Kapisa      کاپیسا       AF02     None       None
# 5     1.810899        Paktika      پکتیکا       AF12     None       None
# 6     0.794449         Kunduz        کندز       AF19     None       None
# 7     5.749524        Hilmand       هلمند       AF30     None       None
# 8     1.324432       Daykundi     دایکندی       AF24     None       None
# 9     1.627631          Zabul        زابل       AF26     None       None
# 10    5.139095       Kandahar      کندهار       AF27     None       None
# 11    2.081709         Faryab      فاریاب       AF29     None       None
# 12    0.371500       Panjsher      پنجشیر       AF08     None       None
# 13    1.070422        Jawzjan      جوزجان       AF28     None       None
# 14    1.775660         Bamyan      بامیان       AF10     None       None
# 15    0.460366          Kabul        کابل       AF01     None       None
# 16    1.907544        Badghis      بادغیس       AF31     None       None
# 17    3.925013          Farah        فراه       AF33     None       None
# 18    0.531138         Paktya       پکتیا       AF13     None       None
# 19    1.491713      Sar-e-Pul        سرپل       AF22     None       None
# 20    1.057376  Maidan Wardak  میدان وردک       AF04     None       None
# 21    1.763071          Balkh         بلخ       AF21     None       None
# 22    1.252758         Takhar        تخار       AF18     None       None
# 23    0.384020        Laghman       لغمان       AF07     None       None
# 24    1.344434       Samangan      سمنگان       AF20     None       None
# 25    0.428761          Logar        لوگر       AF05     None       None
# 26    0.416132          Kunar      کنر ها       AF15     None       None
# 27    4.392619     Badakhshan      بدخشان       AF17     None       None
# 28    1.701746        Baghlan       بغلان       AF09     None       None
# 29    0.550813         Parwan       پروان       AF03     None       None
# 30    0.398140          Khost        خوست       AF14     None       None
# 31    6.007026          Hirat        هرات       AF32     None       None
# 32    0.721955      Nangarhar     ننگرهار       AF06     None       None
# 33    3.802547           Ghor         غور       AF23     None       None
#
#    adm1alt2en adm1alt1da adm1alt2da      adm0_en    adm0_da adm0_pcode  \
# 0        None       None       None  Afghanistan  افغانستان         AF
# 1        None       None       None  Afghanistan  افغانستان         AF
# 2        None       None       None  Afghanistan  افغانستان         AF
# 3        None       None       None  Afghanistan  افغانستان         AF
# 4        None       None       None  Afghanistan  افغانستان         AF
# 5        None       None       None  Afghanistan  افغانستان         AF
# 6        None       None       None  Afghanistan  افغانستان         AF
# 7        None       None       None  Afghanistan  افغانستان         AF
# 8        None       None       None  Afghanistan  افغانستان         AF
# 9        None       None       None  Afghanistan  افغانستان         AF
# 10       None       None       None  Afghanistan  افغانستان         AF
# 11       None       None       None  Afghanistan  افغانستان         AF
# 12       None       None       None  Afghanistan  افغانستان         AF
# 13       None       None       None  Afghanistan  افغانستان         AF
# 14       None       None       None  Afghanistan  افغانستان         AF
# 15       None       None       None  Afghanistan  افغانستان         AF
# 16       None       None       None  Afghanistan  افغانستان         AF
# 17       None       None       None  Afghanistan  افغانستان         AF
# 18       None       None       None  Afghanistan  افغانستان         AF
# 19       None       None       None  Afghanistan  افغانستان         AF
# 20       None       None       None  Afghanistan  افغانستان         AF
# 21       None       None       None  Afghanistan  افغانستان         AF
# 22       None       None       None  Afghanistan  افغانستان         AF
# 23       None       None       None  Afghanistan  افغانستان         AF
# 24       None       None       None  Afghanistan  افغانستان         AF
# 25       None       None       None  Afghanistan  افغانستان         AF
# 26       None       None       None  Afghanistan  افغانستان         AF
# 27       None       None       None  Afghanistan  افغانستان         AF
# ...
# 0         None       None       None     Badakhshan      بدخشان       AF17
# 1         None       None       None       Samangan      سمنگان       AF20
# 2         None       None       None          Logar        لوگر       AF05
# 3         None       None       None  Maidan Wardak  میدان وردک       AF04
# 4         None       None       None          Farah        فراه       AF33
# ..         ...        ...        ...            ...         ...        ...
# 396       None       None       None          Khost        خوست       AF14
# 397       None       None       None         Faryab      فاریاب       AF29
# 398       None       None       None          Kabul        کابل       AF01
# 399       None       None       None        Badghis      بادغیس       AF31
# 400       None       None       None          Hirat        هرات       AF32
#
#          adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# ..           ...        ...        ...         ...         ...     ...
# 396  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 397  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 398  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 399  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 400  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#             reg_en           reg_da reg_pcode    km2_029cm  pop_sum_029cm  \
# 0    North Eastern  سهیل ختیځه حوزه        NE     7.114073    2132.527344
# 1         Northern       سهیلی حوزه        NR   146.655092    8728.083984
# 2          Capital       مرکزی حوزه        CR   194.437138   45675.617188
# 3          Capital       مرکزی حوزه        CR    27.688561    4012.395020
# 4          Western     لویدیځه حوزه        WR   791.319585   36589.214844
# ..             ...              ...       ...          ...            ...
# 396  South Eastern  جنوب ختیځه حوزه        SE    11.364953    2522.822266
# 397       Northern       سهیلی حوزه        NR   234.342799    8169.594727
# 398        Capital       مرکزی حوزه        CR    47.478736   38620.621094
# 399        Western     لویدیځه حوزه        WR    88.426043    6399.164062
# 400        Western     لویدیځه حوزه        WR  1082.057671    7338.310059
#
#      build_029cm
# 0          169.0
# 1         2167.0
# 2        11173.0
# 3          470.0
# 4         5934.0
# ..           ...
# 396        228.0
# 397       3568.0
# 398       4362.0
# 399       4496.0
# 400       2328.0
#
# [401 rows x 27 columns]
# Finished flood loop nr afg_fldzonea_100k_ncia_v2_029cm_dissolve_all_v2
# Current Time = 09:33:41
#
#
# Starting flood loop nr afg_fldzonea_100k_ncia_v2_121cm_dissolve_all_v2
# Current Time = 09:33:41
# Reprojecting - Start: 09:34:20
# Reprojecting - End:   09:34:24
# Clip - Start:         09:34:24
# Clip - End:           10:51:26
# Area - Start:         10:51:26
# Area - End:           10:51:26
# Buildings - Start:    10:51:26
#     Joining buildings to flood polygons   Start: 10:51:26
#     Joining buildings to flood polygons   End:   11:13:09
#     Counting number of buildings          Start: 11:13:09
#     Counting number of buildings          End:   11:13:09
# Buildings - End:      11:13:09
# Zonalstats - Start:   11:13:09
# Zonalstats - End:     11:14:32
# Merging - Start:      11:14:32
# Merging - End:        11:14:32
#       id                                               geom  shape_leng  \
# 0      1  MULTIPOLYGON (((7867133.864 3802368.500, 78671...    0.803005
# 1      2  MULTIPOLYGON (((7616915.466 3779589.826, 76168...    3.296682
# 2      3  MULTIPOLYGON (((7670834.369 3570001.122, 76708...    1.984007
# 3    118  MULTIPOLYGON (((7600682.499 3516871.898, 76005...    1.197111
# 4    119  MULTIPOLYGON (((7000888.350 3469192.256, 70009...    3.889667
# ..   ...                                                ...         ...
# 396  397  MULTIPOLYGON (((7777453.775 3492136.175, 77773...    1.335641
# 397  398  MULTIPOLYGON (((7190501.742 3763962.455, 71911...    2.748945
# 398  399  MULTIPOLYGON (((7705312.929 3619450.132, 77052...    0.888306
# 399  400  MULTIPOLYGON (((6990707.918 3666460.448, 69907...    2.719759
# 400  401  MULTIPOLYGON (((6961028.661 3499626.035, 69607...    6.382935
#
#      shape_area          adm2_en     adm2_da adm2_pcode adm2_ref adm2alt1en  \
# 0      0.024570            Khash         خاش     AF1705     None       None
# 1      0.211078  Hazrat-e-Sultan  حضرت سلطان     AF2002     None       None
# 2      0.110332       Pul-e-Alam      پل علم     AF0501     None     Centre
# 3      0.057921          Jaghatu        جغتو     AF0408     None       None
# 4      0.531777       Bala Buluk   بالا بلوک     AF3306     None       None
# ..          ...              ...         ...        ...      ...        ...
# 396    0.045657        Musa Khel    موسی خیل     AF1405     None       None
# 397    0.267424      Dawlat Abad   دولت آباد     AF2909     None       None
# 398    0.021106        Qara Bagh     قره باغ     AF0114     None       None
# 399    0.228261        Ab Kamari     آب کمری     AF3102     None       None
# 400    0.789024         Adraskan      ادرسکن     AF3209     None       None
#
#     adm2alt2en adm2alt1da adm2alt2da        adm1_en     adm1_da adm1_pcode  \
# 0         None       None       None     Badakhshan      بدخشان       AF17
# 1         None       None       None       Samangan      سمنگان       AF20
# 2         None       None       None          Logar        لوگر       AF05
# 3         None       None       None  Maidan Wardak  میدان وردک       AF04
# 4         None       None       None          Farah        فراه       AF33
# ..         ...        ...        ...            ...         ...        ...
# 396       None       None       None          Khost        خوست       AF14
# 397       None       None       None         Faryab      فاریاب       AF29
# 398       None       None       None          Kabul        کابل       AF01
# 399       None       None       None        Badghis      بادغیس       AF31
# 400       None       None       None          Hirat        هرات       AF32
#
#          adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# ..           ...        ...        ...         ...         ...     ...
# 396  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 397  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 398  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 399  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 400  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#             reg_en           reg_da reg_pcode    km2_029cm  pop_sum_029cm  \
# 0    North Eastern  سهیل ختیځه حوزه        NE     7.114073    2132.527344
# 1         Northern       سهیلی حوزه        NR   146.655092    8728.083984
# 2          Capital       مرکزی حوزه        CR   194.437138   45675.617188
# 3          Capital       مرکزی حوزه        CR    27.688561    4012.395020
# 4          Western     لویدیځه حوزه        WR   791.319585   36589.214844
# ..             ...              ...       ...          ...            ...
# 396  South Eastern  جنوب ختیځه حوزه        SE    11.364953    2522.822266
# 397       Northern       سهیلی حوزه        NR   234.342799    8169.594727
# 398        Capital       مرکزی حوزه        CR    47.478736   38620.621094
# 399        Western     لویدیځه حوزه        WR    88.426043    6399.164062
# 400        Western     لویدیځه حوزه        WR  1082.057671    7338.310059
#
#      build_029cm   km2_121cm  pop_sum_121cm  build_121cm
# 0          169.0    4.276485    1365.696411         93.0
# 1         2167.0   89.284107    5548.818848       1224.0
# 2        11173.0  104.601843   26355.265625       5245.0
# 3          470.0   13.935666    2030.751587        129.0
# 4         5934.0  457.999837   21884.498047       3233.0
# ..           ...         ...            ...          ...
# 396        228.0    7.308617    1669.609375        143.0
# 397       3568.0  140.369792    4865.295898       1734.0
# 398       4362.0   19.059837   14276.693359       1599.0
# 399       4496.0   59.298972    4483.372559       3031.0
# 400       2328.0  574.698532    4397.174316       1119.0
#
# [401 rows x 30 columns]
# Finished flood loop nr afg_fldzonea_100k_ncia_v2_121cm_dissolve_all_v2
# Current Time = 11:14:32
#
#
# Starting flood loop nr afg_fldzonea_100k_ncia_v2_271cm_dissolve_all_v2
# Current Time = 11:14:32
# Reprojecting - Start: 11:14:44
# Reprojecting - End:   11:14:45
# Clip - Start:         11:14:45
# Clip - End:           11:21:41
# Area - Start:         11:21:41
# Area - End:           11:21:41
# Buildings - Start:    11:21:41
#     Joining buildings to flood polygons   Start: 11:21:41
#     Joining buildings to flood polygons   End:   11:29:15
#     Counting number of buildings          Start: 11:29:15
#     Counting number of buildings          End:   11:29:15
# Buildings - End:      11:29:15
# Zonalstats - Start:   11:29:15
# Zonalstats - End:     11:29:51
# Merging - Start:      11:29:51
# Merging - End:        11:29:51
#       id                                               geom  shape_leng  \
# 0      1  MULTIPOLYGON (((7867133.864 3802368.500, 78671...    0.803005
# 1      2  MULTIPOLYGON (((7616915.466 3779589.826, 76168...    3.296682
# 2      3  MULTIPOLYGON (((7670834.369 3570001.122, 76708...    1.984007
# 3    118  MULTIPOLYGON (((7600682.499 3516871.898, 76005...    1.197111
# 4    119  MULTIPOLYGON (((7000888.350 3469192.256, 70009...    3.889667
# ..   ...                                                ...         ...
# 396  397  MULTIPOLYGON (((7777453.775 3492136.175, 77773...    1.335641
# 397  398  MULTIPOLYGON (((7190501.742 3763962.455, 71911...    2.748945
# 398  399  MULTIPOLYGON (((7705312.929 3619450.132, 77052...    0.888306
# 399  400  MULTIPOLYGON (((6990707.918 3666460.448, 69907...    2.719759
# 400  401  MULTIPOLYGON (((6961028.661 3499626.035, 69607...    6.382935
#
#      shape_area          adm2_en     adm2_da adm2_pcode adm2_ref adm2alt1en  \
# 0      0.024570            Khash         خاش     AF1705     None       None
# 1      0.211078  Hazrat-e-Sultan  حضرت سلطان     AF2002     None       None
# 2      0.110332       Pul-e-Alam      پل علم     AF0501     None     Centre
# 3      0.057921          Jaghatu        جغتو     AF0408     None       None
# 4      0.531777       Bala Buluk   بالا بلوک     AF3306     None       None
# ..          ...              ...         ...        ...      ...        ...
# 396    0.045657        Musa Khel    موسی خیل     AF1405     None       None
# 397    0.267424      Dawlat Abad   دولت آباد     AF2909     None       None
# 398    0.021106        Qara Bagh     قره باغ     AF0114     None       None
# 399    0.228261        Ab Kamari     آب کمری     AF3102     None       None
# 400    0.789024         Adraskan      ادرسکن     AF3209     None       None
#
#     adm2alt2en adm2alt1da adm2alt2da        adm1_en     adm1_da adm1_pcode  \
# 0         None       None       None     Badakhshan      بدخشان       AF17
# 1         None       None       None       Samangan      سمنگان       AF20
# 2         None       None       None          Logar        لوگر       AF05
# 3         None       None       None  Maidan Wardak  میدان وردک       AF04
# 4         None       None       None          Farah        فراه       AF33
# ..         ...        ...        ...            ...         ...        ...
# 396       None       None       None          Khost        خوست       AF14
# 397       None       None       None         Faryab      فاریاب       AF29
# 398       None       None       None          Kabul        کابل       AF01
# 399       None       None       None        Badghis      بادغیس       AF31
# 400       None       None       None          Hirat        هرات       AF32
#
#          adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# ..           ...        ...        ...         ...         ...     ...
# 396  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 397  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 398  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 399  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 400  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#             reg_en           reg_da reg_pcode    km2_029cm  pop_sum_029cm  \
# 0    North Eastern  سهیل ختیځه حوزه        NE     7.114073    2132.527344
# 1         Northern       سهیلی حوزه        NR   146.655092    8728.083984
# 2          Capital       مرکزی حوزه        CR   194.437138   45675.617188
# 3          Capital       مرکزی حوزه        CR    27.688561    4012.395020
# 4          Western     لویدیځه حوزه        WR   791.319585   36589.214844
# ..             ...              ...       ...          ...            ...
# 396  South Eastern  جنوب ختیځه حوزه        SE    11.364953    2522.822266
# 397       Northern       سهیلی حوزه        NR   234.342799    8169.594727
# 398        Capital       مرکزی حوزه        CR    47.478736   38620.621094
# 399        Western     لویدیځه حوزه        WR    88.426043    6399.164062
# 400        Western     لویدیځه حوزه        WR  1082.057671    7338.310059
#
#      build_029cm   km2_121cm  pop_sum_121cm  build_121cm   km2_271cm  \
# 0          169.0    4.276485    1365.696411         93.0    1.218467
# 1         2167.0   89.284107    5548.818848       1224.0   30.806055
# 2        11173.0  104.601843   26355.265625       5245.0   34.954700
# 3          470.0   13.935666    2030.751587        129.0    4.631009
# 4         5934.0  457.999837   21884.498047       3233.0  104.621476
# ..           ...         ...            ...          ...         ...
# 396        228.0    7.308617    1669.609375        143.0    1.364096
# 397       3568.0  140.369792    4865.295898       1734.0   50.353946
# 398       4362.0   19.059837   14276.693359       1599.0    7.103153
# 399       4496.0   59.298972    4483.372559       3031.0   24.015106
# 400       2328.0  574.698532    4397.174316       1119.0  147.594468
#
#      pop_sum_271cm  build_271cm
# 0       502.802216          4.0
# 1      2310.645264        395.0
# 2     10667.577148       1376.0
# 3       759.671509         22.0
# 4      4025.966553        545.0
# ..             ...          ...
# 396     359.802002         42.0
# 397    1827.658447        295.0
# 398    4552.025879        415.0
# 399    2327.150146       1172.0
# 400    1736.052002        257.0
#
# [401 rows x 33 columns]
# Finished flood loop nr afg_fldzonea_100k_ncia_v2_271cm_dissolve_all_v2
# Current Time = 11:29:51
#
#
# FINISHED WITH  -  afg_admbnda_adm2_flood_stats  - 11:29:52
#
#
#
# ALL PROCESSING END 11:29:52
