# %%
### Script for adding avalanche statistics (buildings, people and km2) to admin polygons
#dissolve across district and province (done in previous script)
#cut by new district and province
#calculate area
#zonal stats on pop
#zonal stats on building centroids
#save to postgres + join back on admin areas

# %%
import json
import geopandas as gpd
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 # required for exporting to postgis
import rioxarray as rxr
from rasterio.crs import CRS
from sqlalchemy import create_engine
import rasterstats
from shapely.ops import transform
from datetime import datetime
import numpy as np

# %% [markdown]
# ### Setting connection and parameters

# %%
# Load database configuration from file
with open(r'D:\iMMAP\code\db_config\hsdc_local_db_config.json', 'r') as f:
    config = json.load(f)

# Create database URL with credentials
db_url = f"postgresql://{config['username']}:{config['password']}@{config['host']}:{config['port']}/{config['database']}"

# Connect to the database
con = create_engine(db_url)

# %%
pd.set_option('display.max_columns', None)

# %%
# Define projection
repro_crs = '+proj=cea'

# %% [markdown]
# ### Defining functions

# %%
# Clipping admin and flood zones
def clip(adm, av):
    av = adm.clip(av)
    return av

# %%
# Extracting area
def area(av):
    col_name = 'm2'
    av[col_name] = av['geom'].area #.div(1000000)
    return av

# %%
# Extracting buildings
def buildings(flood, build_centroids, group_by_parameter):
    
    build_count_column = 'build'
    
    # Join building centroids to flood polygons
    print('    Joining buildings to flood polygons   Start: {}'.format(datetime.now().strftime("%H:%M:%S")))
    joined_df = gpd.sjoin(
        build_centroids,
        flood,
        how='inner',
        predicate='intersects'
    )
    print('    Joining buildings to flood polygons   End:   {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    # Count number of buildings within admin polygons
    print('    Counting number of buildings          Start: {}'.format(datetime.now().strftime("%H:%M:%S")))
    build_count = joined_df.groupby(
        [group_by_parameter],
        as_index=False,
    )['geom'].count() # vuid is arbitrary, we just count the row
    print('    Counting number of buildings          End:   {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    # Change column name to build_count
    build_count.rename(columns = {'geom': build_count_column}, inplace = True)

    # Merge build count back on to admin dataset
    flood = flood.merge(
        build_count, 
        on=group_by_parameter, 
        how='left')
    
    return flood

# %%
# Extracting population
def ZonalStats(shape_gdf, raster, stats):

    zonalSt = rasterstats.zonal_stats(shape_gdf, raster, stats = stats)
    
    df = pd.DataFrame(zonalSt)
    
    df_concat = pd.concat([df, shape_gdf], axis=1)
    
    final_gdf = gpd.GeoDataFrame(df_concat, geometry=df_concat.geom) #wkb_geometry
    
    final_gdf_ordered = final_gdf[[c for c in final_gdf if c not in [stats]] + [stats]]
    
    flood = final_gdf_ordered.rename(columns={"sum": "pop_sum"}) #, inplace=True)
    
    flood = flood.drop(columns=['geometry'])
    
    flood = flood.set_geometry('geom')
    
    return flood

# %% [markdown]
# ### Defining reference paths and lists

# %%
pop_path = r'D:\iMMAP\data\Afghanistan\afg_worldpop_2020_UNadj_unconstrained.tif'
pop_path_cea = r'D:\iMMAP\data\Afghanistan\afg_worldpop_2020_UNadj_unconstrained_projCEA.tif'

admin_list = [
    'afg_admbnda_region',
    'afg_admbnda_adm1',
    'afg_admbnda_adm2'   
]

admin_abbreviations = [
    'region',
    'adm1',
    'adm2'
]

admin_list_groupby = [
    'reg_pcode',
    'adm1_pcode',
    'adm2_pcode'       
]

#av_list = [
#    'afg_avsa_clean_dissolve_testClip'
#]

av_code_list = [
    'High',
    'Moderate'
]

# %% [markdown]
# ### Running functions

# %%
print("Loading buildings. Starting: ", datetime.now().strftime("%H:%M:%S"))
build_centroids = gpd.GeoDataFrame.from_postgis('SELECT * from afg_buildings_microsoft_centroids', con).to_crs(repro_crs) #afg_buildings_microsoft_centroids_testclip #build_testclip2
#build_centroids = gpd.GeoDataFrame.from_postgis('SELECT * from afg_buildings_microsoft_centroids_testclip1_tiny', con).to_crs(repro_crs) #afg_buildings_microsoft_centroids_testclip #build_testclip2
print("Loading buildings. Finished: ", datetime.now().strftime("%H:%M:%S"))
# Out:
# Loading buildings. Starting:  14:53:59
# Loading buildings. Finished:  14:57:19

# %%
print('\n\n\nALL PROCESSING START', datetime.now().strftime("%H:%M:%S"))

for i in range(len(admin_list)):
    
    print('\n\n\n\nStarting admin loop nr {}: {}'.format(i, admin_list[i]))
    
    adm = gpd.GeoDataFrame.from_postgis('SELECT * from {}'.format(admin_list[i]), con)
    
    adm = adm.to_crs(repro_crs)
    
    group_by_parameter = admin_list_groupby[i]
    
    av_name = 'afg_avsa_clean_dissolve'
    
    
    #for av_level in range(len(av_list)):
        
    print("Current Time =", datetime.now().strftime("%H:%M:%S"))
    
    av = gpd.GeoDataFrame.from_postgis('SELECT * from {}'.format(av_name), con, 'wkb_geometry')
    
    print('Reprojecting - Start: {}'.format(datetime.now().strftime("%H:%M:%S")))
    av = av.to_crs(repro_crs) #OBS, if no flood level extent in admin area, then row dissapears from final output
    print('Reprojecting - End:   {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    print('Clip - Start:         {}'.format(datetime.now().strftime("%H:%M:%S")))
    av = clip(adm, av) #.explode()
    print('Clip - End:           {}'.format(datetime.now().strftime("%H:%M:%S")))
    print('Area - Start:         {}'.format(datetime.now().strftime("%H:%M:%S")))
    av = area(av)
    print('Area - End:           {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    print('Buildings - Start:    {}'.format(datetime.now().strftime("%H:%M:%S")))
    av = buildings(av, build_centroids, group_by_parameter)
    print('Buildings - End:      {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    print('Zonalstats - Start:   {}'.format(datetime.now().strftime("%H:%M:%S")))
    av = ZonalStats(av, pop_path_cea, 'sum')
    print('Zonalstats - End:     {}'.format(datetime.now().strftime("%H:%M:%S")))
    
    print('Merging - Start:      {}'.format(datetime.now().strftime("%H:%M:%S")))
    # Subsetting the table to only the columns we want to join
    av = pd.DataFrame(av[[
            '{}'.format(group_by_parameter),
            'm2',
            'pop_sum',
            'build']]
    )
    
    
    # Summaries across columns
    av = av.groupby(group_by_parameter).sum()
    
    
    
    adm = adm.merge(
        av, 
        on=group_by_parameter, 
        how='left')
    print('Merging - End:        {}'.format(datetime.now().strftime("%H:%M:%S")))
   
    print("Current Time =", datetime.now().strftime("%H:%M:%S"))
    
    
    
    # Convering NaN to 0 across stats columns
    test_m2 = adm['m2'].isnull()
    test_pop = adm['pop_sum'].isnull()
    test_build = adm['build'].isnull()

    if len(test_m2.unique()) == 2:
        adm.loc[adm.m2.isnull(), 'm2'] = 0
    
    if len(test_pop.unique()) == 2:
        adm.loc[adm.pop_sum.isnull(), 'pop_sum'] = 0
    
    if len(test_build.unique()) == 2:
        adm.loc[adm.build.isnull(), 'build'] = 0
        
    
    print(adm)
    
    
    # Save to postgis if all flood levels have been processed
    adm = adm.to_crs('epsg:4326')
    adm.to_postgis('afg_admbnda_{}_av_stats'.format(admin_abbreviations[i]), con, if_exists='replace')
    print('\n\nFINISHED WITH  -  afg_admbnda_{}_av_stats  - {}'
                  .format(admin_abbreviations[i], datetime.now().strftime("%H:%M:%S")))
    
print('\n\n\nALL PROCESSING END', datetime.now().strftime("%H:%M:%S"))
# Out:
# ALL PROCESSING START 14:57:19
#
#
#
#
# Starting admin loop nr 0: afg_admbnda_region
# Current Time = 14:57:19
# Reprojecting - Start: 14:58:41
# Reprojecting - End:   14:58:51
# Clip - Start:         14:58:51
# Clip - End:           15:42:45
# Area - Start:         15:42:45
# Area - End:           15:42:45
# Buildings - Start:    15:42:45
#     Joining buildings to flood polygons   Start: 15:42:45
#     Joining buildings to flood polygons   End:   17:51:59
#     Counting number of buildings          Start: 17:51:59
#     Counting number of buildings          End:   17:51:59
# Buildings - End:      17:51:59
# Zonalstats - Start:   17:51:59
# Zonalstats - End:     17:53:56
# Merging - Start:      17:53:56
# Merging - End:        17:54:00
# Current Time = 17:54:00
#    id                                               geom            reg_en  \
# 0   1  MULTIPOLYGON (((7617702.961 3735993.537, 76174...          Northern
# 1   2  MULTIPOLYGON (((7304671.677 3483929.798, 73045...  Central Highland
# 2   3  MULTIPOLYGON (((7588786.360 3345978.293, 75886...     South Eastern
# 3   4  MULTIPOLYGON (((7523765.643 3314826.127, 75237...          Southern
# 4   5  MULTIPOLYGON (((7792666.678 3551912.629, 77925...           Eastern
# 5   6  MULTIPOLYGON (((7488668.638 3545395.217, 74884...           Capital
# 6   7  MULTIPOLYGON (((7925357.856 3733126.513, 79252...     North Eastern
# 7   8  MULTIPOLYGON (((6859234.301 3303643.897, 68575...           Western
#
#             reg_da reg_pcode reg_ref regalt1en regalt2en regalt1da regalt2da  \
# 0       سهیلی حوزه        NR    None      None      None      None      None
# 1  لوړه مرکزی حوزه        CH    None      None      None      None      None
# 2  جنوب ختیځه حوزه        SE    None      None      None      None      None
# 3       جنوبی حوزه        SR    None      None      None      None      None
# 4       ختیځه حوزه        ER    None      None      None      None      None
# 5       مرکزی حوزه        CR    None      None      None      None      None
# 6  سهیل ختیځه حوزه        NE    None      None      None      None      None
# 7     لویدیځه حوزه        WR    None      None      None      None      None
#
#        adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 5  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 6  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 7  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 26  27  MULTIPOLYGON (((7907657.034 3599715.603, 79075...    4.027321
# 27  28  MULTIPOLYGON (((7925357.856 3733126.513, 79252...   21.397249
# 28  29  MULTIPOLYGON (((7771653.105 3703978.236, 77717...    7.376086
# 29  30  MULTIPOLYGON (((7672078.078 3621236.357, 76720...    5.324653
# 30  31  MULTIPOLYGON (((7720188.485 3459983.234, 77203...    3.993206
# 31  32  MULTIPOLYGON (((6909538.986 3444256.527, 69093...   16.065633
# 32  33  MULTIPOLYGON (((7892732.692 3546409.944, 78926...    5.325266
# 33  34  MULTIPOLYGON (((7193950.493 3476757.063, 71939...   15.387878
#
#     shape_area        adm1_en     adm1_da adm1_pcode adm1_ref adm1alt1en  \
# 0     2.085632         Ghazni        غزنی       AF11     None       None
# 1     3.794569         Nimroz      نیمروز       AF34     None       None
# 2     0.950518       Nuristan     نورستان       AF16     None       None
# 3     1.265532        Uruzgan      ارزگان       AF25     None       None
# 4     0.185458         Kapisa      کاپیسا       AF02     None       None
# 5     1.810899        Paktika      پکتیکا       AF12     None       None
# 6     0.794449         Kunduz        کندز       AF19     None       None
# 7     5.749524        Hilmand       هلمند       AF30     None       None
# 8     1.324432       Daykundi     دایکندی       AF24     None       None
# 9     1.627631          Zabul        زابل       AF26     None       None
# 10    5.139095       Kandahar      کندهار       AF27     None       None
# 11    2.081709         Faryab      فاریاب       AF29     None       None
# 12    0.371500       Panjsher      پنجشیر       AF08     None       None
# 13    1.070422        Jawzjan      جوزجان       AF28     None       None
# 14    1.775660         Bamyan      بامیان       AF10     None       None
# 15    0.460366          Kabul        کابل       AF01     None       None
# 16    1.907544        Badghis      بادغیس       AF31     None       None
# 17    3.925013          Farah        فراه       AF33     None       None
# 18    0.531138         Paktya       پکتیا       AF13     None       None
# 19    1.491713      Sar-e-Pul        سرپل       AF22     None       None
# 20    1.057376  Maidan Wardak  میدان وردک       AF04     None       None
# 21    1.763071          Balkh         بلخ       AF21     None       None
# 22    1.252758         Takhar        تخار       AF18     None       None
# 23    0.384020        Laghman       لغمان       AF07     None       None
# 24    1.344434       Samangan      سمنگان       AF20     None       None
# 25    0.428761          Logar        لوگر       AF05     None       None
# 26    0.416132          Kunar      کنر ها       AF15     None       None
# 27    4.392619     Badakhshan      بدخشان       AF17     None       None
# 28    1.701746        Baghlan       بغلان       AF09     None       None
# 29    0.550813         Parwan       پروان       AF03     None       None
# 30    0.398140          Khost        خوست       AF14     None       None
# 31    6.007026          Hirat        هرات       AF32     None       None
# 32    0.721955      Nangarhar     ننگرهار       AF06     None       None
# 33    3.802547           Ghor         غور       AF23     None       None
#
#    adm1alt2en adm1alt1da adm1alt2da      adm0_en    adm0_da adm0_pcode  \
# 0        None       None       None  Afghanistan  افغانستان         AF
# 1        None       None       None  Afghanistan  افغانستان         AF
# 2        None       None       None  Afghanistan  افغانستان         AF
# 3        None       None       None  Afghanistan  افغانستان         AF
# 4        None       None       None  Afghanistan  افغانستان         AF
# 5        None       None       None  Afghanistan  افغانستان         AF
# 6        None       None       None  Afghanistan  افغانستان         AF
# 7        None       None       None  Afghanistan  افغانستان         AF
# 0         SE  6.859470e+08   24090.109375   1690.0
# 1         SR  0.000000e+00       0.000000      0.0
# 2         ER  1.559838e+09   39018.617188   1238.0
# 3         SR  1.644800e+09   43988.453125   2455.0
# 4         CR  3.690174e+08   59995.781250   3280.0
# 5         SE  1.143497e+08    3269.859131    175.0
# 6         NE  9.559450e+06     424.870941     17.0
# 7         SR  1.007191e+09   22513.718750   1131.0
# 8         CH  1.913554e+09   66420.695312   9695.0
# 9         SR  5.894767e+08   13294.404297    896.0
# 10        SR  5.330209e+08    5843.333496    257.0
# 11        NR  5.949484e+08   27946.328125   3064.0
# 12        CR  7.169520e+08   50498.988281   6658.0
# 13        NR  1.112650e+07    1373.850952     35.0
# 14        CH  1.469210e+09   49883.218750   7935.0
# 15        CR  3.641596e+08   86245.304688   7881.0
# 16        WR  6.066601e+08   13498.084961   3046.0
# 17        WR  2.050432e+09   21008.468750    838.0
# 18        SE  2.771452e+08   35697.656250    988.0
# 19        NR  1.490353e+09   36200.957031   9121.0
# 20        CR  5.375690e+08   32729.845703   2246.0
# 21        NR  2.620648e+08    9999.444336   1571.0
# 22        NE  1.378584e+09   56752.750000   6816.0
# 23        ER  3.476443e+08   28073.496094   1048.0
# 24        NR  6.238209e+08   20136.642578   5026.0
# 25        CR  2.218543e+08   13646.912109    455.0
# 26        ER  3.240609e+08   31223.353516    762.0
# 27        NE  7.007532e+09  257381.390625  15826.0
# 28        NE  2.404388e+09   87831.171875  11151.0
# 29        CR  7.767878e+08   62263.066406   5847.0
# 30        SE  1.355663e+08   15784.888672    669.0
# 31        WR  9.624407e+08   16863.548828    778.0
# 32        ER  3.108545e+08   27800.337891    784.0
# 33        WR  2.451298e+09   66256.953125  15487.0
# FINISHED WITH  -  afg_admbnda_adm1_av_stats  - 19:05:25
#
#
#
#
# Starting admin loop nr 2: afg_admbnda_adm2
# Current Time = 19:05:25
# Reprojecting - Start: 19:06:45
# Reprojecting - End:   19:06:54
# Clip - Start:         19:06:54
# Clip - End:           19:58:00
# Area - Start:         19:58:00
# Area - End:           19:58:00
# Buildings - Start:    19:58:00
#     Joining buildings to flood polygons   Start: 19:58:00
#     Joining buildings to flood polygons   End:   20:00:56
#     Counting number of buildings          Start: 20:00:56
#     Counting number of buildings          End:   20:00:56
# Buildings - End:      20:00:56
# Zonalstats - Start:   20:00:56
# Zonalstats - End:     20:03:18
# Merging - Start:      20:03:18
# Merging - End:        20:03:23
# Current Time = 20:03:23
#       id                                               geom  shape_leng  \
# 0      1  MULTIPOLYGON (((7867133.864 3802368.500, 78671...    0.803005
# 1      2  MULTIPOLYGON (((7616915.466 3779589.826, 76168...    3.296682
# 2      3  MULTIPOLYGON (((7670834.369 3570001.122, 76708...    1.984007
# 3    118  MULTIPOLYGON (((7600682.499 3516871.898, 76005...    1.197111
# 4    119  MULTIPOLYGON (((7000888.350 3469192.256, 70009...    3.889667
# ..   ...                                                ...         ...
# 396  397  MULTIPOLYGON (((7777453.775 3492136.175, 77773...    1.335641
# 397  398  MULTIPOLYGON (((7190501.742 3763962.455, 71911...    2.748945
# 398  399  MULTIPOLYGON (((7705312.929 3619450.132, 77052...    0.888306
# 399  400  MULTIPOLYGON (((6990707.918 3666460.448, 69907...    2.719759
# 400  401  MULTIPOLYGON (((6961028.661 3499626.035, 69607...    6.382935
#
#      shape_area          adm2_en     adm2_da adm2_pcode adm2_ref adm2alt1en  \
# 0      0.024570            Khash         خاش     AF1705     None       None
# 1      0.211078  Hazrat-e-Sultan  حضرت سلطان     AF2002     None       None
# 2      0.110332       Pul-e-Alam      پل علم     AF0501     None     Centre
# 3      0.057921          Jaghatu        جغتو     AF0408     None       None
# 4      0.531777       Bala Buluk   بالا بلوک     AF3306     None       None
# ..          ...              ...         ...        ...      ...        ...
# 396    0.045657        Musa Khel    موسی خیل     AF1405     None       None
# 397    0.267424      Dawlat Abad   دولت آباد     AF2909     None       None
# 398    0.021106        Qara Bagh     قره باغ     AF0114     None       None
# 399    0.228261        Ab Kamari     آب کمری     AF3102     None       None
# 400    0.789024         Adraskan      ادرسکن     AF3209     None       None
#
#     adm2alt2en adm2alt1da adm2alt2da        adm1_en     adm1_da adm1_pcode  \
# 0         None       None       None     Badakhshan      بدخشان       AF17
# 1         None       None       None       Samangan      سمنگان       AF20
# 2         None       None       None          Logar        لوگر       AF05
# 3         None       None       None  Maidan Wardak  میدان وردک       AF04
# 4         None       None       None          Farah        فراه       AF33
# ..         ...        ...        ...            ...         ...        ...
# 396       None       None       None          Khost        خوست       AF14
# 397       None       None       None         Faryab      فاریاب       AF29
# 398       None       None       None          Kabul        کابل       AF01
# 399       None       None       None        Badghis      بادغیس       AF31
# 400       None       None       None          Hirat        هرات       AF32
#
#          adm0_en    adm0_da adm0_pcode        date     validon validto  \
# 0    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 1    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 2    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 3    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 4    Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# ..           ...        ...        ...         ...         ...     ...
# 396  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 397  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 398  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 399  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
# 400  Afghanistan  افغانستان         AF  2017-12-12  2021-11-17    None
#
#             reg_en           reg_da reg_pcode            m2       pop_sum  \
# 0    North Eastern  سهیل ختیځه حوزه        NE  6.907272e+07  15478.792969
# 1         Northern       سهیلی حوزه        NR  6.354173e+07   2593.608887
# 2          Capital       مرکزی حوزه        CR  2.720636e+07   1614.988525
# 3          Capital       مرکزی حوزه        CR  1.696548e+07   1145.059570
# 4          Western     لویدیځه حوزه        WR  2.497223e+08   1604.139282
# ..             ...              ...       ...           ...           ...
# 396  South Eastern  جنوب ختیځه حوزه        SE  3.748714e+07   5800.340820
# 397       Northern       سهیلی حوزه        NR  8.062910e+04      4.286321
# 398        Capital       مرکزی حوزه        CR  1.820355e+07   2336.915039
# 399        Western     لویدیځه حوزه        WR  3.121203e+06    157.675964
# 400        Western     لویدیځه حوزه        WR  1.238909e+08   1145.015259
#
#      build
# 0    791.0
# 1    199.0
# 2     17.0
# 3      2.0
# 4     48.0
# ..     ...
# 396  133.0
# 397    0.0
# 398   12.0
# 399   45.0
# 400   27.0
#
# [401 rows x 27 columns]
#
#
# FINISHED WITH  -  afg_admbnda_adm2_av_stats  - 20:03:24
#
#
#
# ALL PROCESSING END 20:03:24

# %%
# Out:
#        ogc_fid avalanche_  avalanch_1              avalanch_2  avalanch_3  \
# 0      25500.0       High     84703.0  Chute and run-out area    868769.0
# 1     192764.0   Moderate     81374.0  Chute and run-out area     71357.0
# 2     193333.0   Moderate     81642.0  Chute and run-out area     67429.0
# 3     193911.0   Moderate     81940.0  Chute and run-out area    245715.0
# 4     194475.0   Moderate     82221.0  Chute and run-out area     57366.0
# ...        ...        ...         ...                     ...         ...
# 6699  249488.0   Moderate    111647.0            Trigger area         NaN
# 6700  249503.0   Moderate    111656.0  Chute and run-out area    127759.0
# 6701  249504.0   Moderate    111656.0            Trigger area         NaN
# 6702  249577.0   Moderate    111696.0            Trigger area         NaN
# 6703  249576.0   Moderate    111696.0  Chute and run-out area     28563.0
#
#       avalanch_4      basin_id                source  sum_area_s avalanch_5  \
# 0         2274.0  2.023305e+09  E. Hagen. iMMAP 2015    543196.0       None
# 1          476.0  2.023305e+09  E. Hagen. iMMAP 2015        25.0       None
# 2          358.0  2.023305e+09  E. Hagen. iMMAP 2015        22.0       None
# 3          954.0  2.023305e+09  E. Hagen. iMMAP 2015       928.0       None
# 4          556.0  2.023305e+09  E. Hagen. iMMAP 2015       237.0       None
# ...          ...           ...                   ...         ...        ...
# 6699       493.0  2.023305e+09  E. Hagen. iMMAP 2015     24007.0       None
# 6700      1060.0  2.023305e+09  E. Hagen. iMMAP 2015    110599.0       None
# 6701      1060.0  2.023305e+09  E. Hagen. iMMAP 2015     17396.0       None
# 6702       414.0  2.023305e+09  E. Hagen. iMMAP 2015      2018.0       None
# 6703       414.0  2.023305e+09  E. Hagen. iMMAP 2015     26890.0       None
#
#      area_build  shape_leng    shape_area  basinmembe       _sum    area  \
# 0          None    0.066591  5.271763e-05      3793.0  18.557033  542926
# 1          None    0.000235  2.472588e-09      3790.0   0.000773      25
# 2          None    0.000229  2.154863e-09      3790.0   0.001321      22
# 3          None    0.001652  9.002248e-08      3790.0   0.028118     928
# 4          None    0.001004  2.296441e-08      3901.0   0.004862     237
# ...         ...         ...           ...         ...        ...     ...
# 6699       None    0.007019  2.340339e-06      3787.0   1.421876   23993
# 6700       None    0.022930  1.078099e-05      3787.0   5.704434  110535
# 6701       None    0.007035  1.695786e-06      3787.0   0.713512   17386
# 6702       None    0.001858  1.967375e-07      3787.0   0.100846    2017
# 6703       None    0.009703  2.621265e-06      3787.0   1.448547   26874
#
#                                                geometry
# 0     POLYGON ((66.53948 33.56908, 66.53959 33.56899...
# 1     POLYGON ((66.36637 33.50999, 66.36630 33.51003...
# 2     POLYGON ((66.36778 33.51321, 66.36778 33.51322...
# 3     POLYGON ((66.37829 33.52253, 66.37830 33.52265...
# 4     POLYGON ((66.77621 33.53051, 66.77617 33.53051...
# ...                                                 ...
# 6699  POLYGON ((66.44671 33.96202, 66.44677 33.96200...
# 6700  POLYGON ((66.44336 33.95863, 66.44337 33.95859...
# 6701  POLYGON ((66.44336 33.95863, 66.44335 33.95863...
# 6702  POLYGON ((66.45015 33.96018, 66.45029 33.96006...
# 6703  POLYGON ((66.45056 33.95979, 66.45057 33.95969...
#
# [6704 rows x 17 columns]

# %%
# Out:
# 11384.583295929046

# %%
# Out:
# 240861330
