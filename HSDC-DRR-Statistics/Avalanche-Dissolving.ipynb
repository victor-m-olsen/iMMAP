# %%
import json
import geopandas as gpd
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine

# %%
# Load database configuration from file
with open(r'D:\iMMAP\code\db_config\hsdc_local_db_config.json', 'r') as f:
    config = json.load(f)

# Create database URL with credentials
db_url = f"postgresql://{config['username']}:{config['password']}@{config['host']}:{config['port']}/{config['database']}"

# Connect to the database
con = create_engine(db_url)

# %%
# Define projection
repro_crs = 'epsg:4326'

# Load data and reproject
av = gpd.GeoDataFrame.from_postgis('SELECT * from afg_avsa_clean', con, 'wkb_geometry').to_crs(repro_crs)

# %%
av
# Out:
#         ogc_fid                                       wkb_geometry  \
# 0        768381  MULTIPOLYGON (((70.71088 37.09350, 70.71086 37...
# 1        768720  MULTIPOLYGON (((71.22247 37.09170, 71.22250 37...
# 2        768382  MULTIPOLYGON (((70.71199 37.09384, 70.71202 37...
# 3        769286  MULTIPOLYGON (((70.74028 37.10278, 70.74028 37...
# 4        768383  MULTIPOLYGON (((70.84938 37.08758, 70.84951 37...
# ...         ...                                                ...
# 845525   768371  MULTIPOLYGON (((70.88045 37.08697, 70.88048 37...
# 845526   768372  MULTIPOLYGON (((70.88268 37.08340, 70.88268 37...
# 845527   768373  MULTIPOLYGON (((70.23647 37.09702, 70.23647 37...
# 845528   768374  MULTIPOLYGON (((70.23647 37.09702, 70.23641 37...
# 845529   768375  MULTIPOLYGON (((71.41006 37.07682, 71.41003 37...
#
#        avalanche_cat  avalanche_id          avalanche_zone  avalanche_area  \
# 0           Moderate        314354  Chute and run-out area        276501.0
# 1           Moderate        314617            Trigger area             NaN
# 2           Moderate        314354            Trigger area             NaN
# 3           Moderate        315008            Trigger area             NaN
# 4           Moderate        314359  Chute and run-out area         63579.0
# ...              ...           ...                     ...             ...
# 845525      Moderate        314346  Chute and run-out area        131595.0
# 845526      Moderate        314346            Trigger area             NaN
# 845527      Moderate        314350  Chute and run-out area         51260.0
# 845528      Moderate        314350            Trigger area             NaN
# 845529      Moderate        314351            Trigger area          2041.0
#
#         avalanche_lenght_m      basin_id                source  sum_area_sqm  \
# 0                    723.0  2.023402e+09  E. Hagen. iMMAP 2015        188279
# 1                    813.0  2.023402e+09  E. Hagen. iMMAP 2015          3651
# 2                    723.0  2.023402e+09  E. Hagen. iMMAP 2015         86825
# 3                    327.0  2.023402e+09  E. Hagen. iMMAP 2015         10665
# 4                    477.0  2.023402e+09  E. Hagen. iMMAP 2015         55085
# ...                    ...           ...                   ...           ...
# 845525               708.0  2.023402e+09  E. Hagen. iMMAP 2015         90268
# 845526               708.0  2.023402e+09  E. Hagen. iMMAP 2015         42381
# 845527               333.0  2.023402e+09  E. Hagen. iMMAP 2015         44403
# 845528               333.0  2.023402e+09  E. Hagen. iMMAP 2015          6854
# 845529                70.0  2.023401e+09  E. Hagen. iMMAP 2015          2041
#
#        avalanche_pop area_buildings  shape_length    shape_area  \
# 0               None           None      0.023299  1.908724e-05
# 1               None           None      0.003176  3.700156e-07
# 2               None           None      0.015763  8.801988e-06
# 3               None           None      0.004491  1.081289e-06
# 4               None           None      0.015613  5.583398e-06
# ...              ...            ...           ...           ...
# 845525          None           None      0.018111  9.148943e-06
# 845526          None           None      0.009058  4.295541e-06
# 845527          None           None      0.009405  4.502934e-06
# 845528          None           None      0.003869  6.950714e-07
# 845529          None           None      0.001888  2.067651e-07
#
#         basinmember_id
# 0                 5064
# 1                 5068
# 2                 5064
# 3                 5064
# 4                 5066
# ...                ...
# 845525            5066
# 845526            5066
# 845527            5184
# 845528            5184
# 845529            4853
#
# [845530 rows x 15 columns]

# %%
# Dissolving by province
av_dissolved = av.dissolve(by='avalanche_cat').explode()

#av_dissolved_clean = av_dissolved.set_index('ogc_fid')[['wkb_geometry', 'avalanche_cat']]
# Out:
# C:\Users\VMO\AppData\Local\Temp\ipykernel_3064\4006814836.py:2: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   av_dissolved = av.dissolve(by='avalanche_cat').explode()

# %%
av_dissolved = av_dissolved.reset_index()

# %%
# Save to PostGIS
av_dissolved.to_postgis("afg_avsa_clean_dissolve", con, if_exists='replace')
