# %%
import geopandas as gpd
from geopandas.tools import sjoin
import pandas as pd
import os

pointInPolys = sjoin(points, uk, how='left')
pointInPolys.head()

# %%
os.chdir('D:\iMMAP\proj\ASDC\data\OCHA-Received\\')

# %%
afg = gpd.read_file(r"D:\iMMAP\data\Afghanistan\AFG_AdminBoundaries_AGCHO_20211117\Shapefiles\afg_admbnda_adm0_agcho_20211117.shp")

# %%
panda_df = pd.read_csv('airports.csv', delimiter=',', decimal='.')

# %%
panda_df
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 74174   46378  ZZ-0001       heliport                     Sealand Helipad
# 74175  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 74176  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 74177  342102     ZZZW         closed              Scandium City Heliport
# 74178  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 1         38.704022    -101.473911        3435.0       NaN          US
# 2         59.947733    -151.692524         450.0       NaN          US
# 3         34.864799     -86.770302         820.0       NaN          US
# 4         35.608700     -91.254898         237.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 74174     51.894444       1.482500          40.0        EU          GB
# 74175    -11.584278      47.296389          11.0        AF          TF
# 74176     32.110587     -97.356312         690.0       NaN          US
# 74177     69.355287    -138.939310           4.0       NaN          CA
# 74178     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# 0          US-PA             Bensalem                no      00A       NaN
# 1          US-KS                Leoti                no     00AA       NaN
# 2          US-AK         Anchor Point                no     00AK       NaN
# 3          US-AL              Harvest                no     00AL       NaN
# 4          US-AR              Newport                no      NaN       NaN
# ...          ...                  ...               ...      ...       ...
# 74174     GB-ENG              Sealand                no      NaN       NaN
# 74175     TF-U-A     Grande Glorieuse                no      NaN       NaN
# 74176      US-TX                 Blum                no     87TX       NaN
# 74177      CA-YT  (Old) Scandium City                no      NaN       NaN
# 74178      JP-46              Mishima                no     RJX7       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 1           00AA                         NaN
# 2           00AK                         NaN
# 3           00AL                         NaN
# 4            NaN                         NaN
# ...          ...                         ...
# 74174        NaN  http://www.sealandgov.org/
# 74175        NaN                         NaN
# 74176       87TX                         NaN
# 74177        NaN                         NaN
# 74178       RJX7                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 74174  https://en.wikipedia.org/wiki/Principality_of_...
# 74175                                                NaN
# 74176                                                NaN
# 74177                                                NaN
# 74178  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# ...                      ...
# 74174   Roughs Tower Helipad
# 74175                    NaN
# 74176                    NaN
# 74177  ZZZW, ZZZW, ZYW, YK96
# 74178   SATSUMA,IWOJIMA,RJX7
#
# [74179 rows x 18 columns]

# %%
geo_df = gpd.GeoDataFrame(
    panda_df, geometry=gpd.points_from_xy(panda_df.longitude_deg, panda_df.latitude_deg))

# %%
geo_df
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 74174   46378  ZZ-0001       heliport                     Sealand Helipad
# 74175  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 74176  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 74177  342102     ZZZW         closed              Scandium City Heliport
# 74178  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 1         38.704022    -101.473911        3435.0       NaN          US
# 2         59.947733    -151.692524         450.0       NaN          US
# 3         34.864799     -86.770302         820.0       NaN          US
# 4         35.608700     -91.254898         237.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 74174     51.894444       1.482500          40.0        EU          GB
# 74175    -11.584278      47.296389          11.0        AF          TF
# 74176     32.110587     -97.356312         690.0       NaN          US
# 74177     69.355287    -138.939310           4.0       NaN          CA
# 74178     30.784722     130.270556         338.0        AS          JP
#
#       iso_region         municipality scheduled_service gps_code iata_code  \
# 0          US-PA             Bensalem                no      00A       NaN
# 1          US-KS                Leoti                no     00AA       NaN
# 2          US-AK         Anchor Point                no     00AK       NaN
# 3          US-AL              Harvest                no     00AL       NaN
# 4          US-AR              Newport                no      NaN       NaN
# ...          ...                  ...               ...      ...       ...
# 74174     GB-ENG              Sealand                no      NaN       NaN
# 74175     TF-U-A     Grande Glorieuse                no      NaN       NaN
# 74176      US-TX                 Blum                no     87TX       NaN
# 74177      CA-YT  (Old) Scandium City                no      NaN       NaN
# 74178      JP-46              Mishima                no     RJX7       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 1           00AA                         NaN
# 2           00AK                         NaN
# 3           00AL                         NaN
# 4            NaN                         NaN
# ...          ...                         ...
# 74174        NaN  http://www.sealandgov.org/
# 74175        NaN                         NaN
# 74176       87TX                         NaN
# 74177        NaN                         NaN
# 74178       RJX7                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 74174  https://en.wikipedia.org/wiki/Principality_of_...
# 74175                                                NaN
# 74176                                                NaN
# 74177                                                NaN
# 74178  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords                     geometry
# 0                        NaN   POINT (-74.93360 40.07080)
# 1                        NaN  POINT (-101.47391 38.70402)
# 2                        NaN  POINT (-151.69252 59.94773)
# 3                        NaN   POINT (-86.77030 34.86480)
# 4                       00AR   POINT (-91.25490 35.60870)
# ...                      ...                          ...
# 74174   Roughs Tower Helipad     POINT (1.48250 51.89444)
# 74175                    NaN   POINT (47.29639 -11.58428)
# 74176                    NaN   POINT (-97.35631 32.11059)
# 74177  ZZZW, ZZZW, ZYW, YK96  POINT (-138.93931 69.35529)
# 74178   SATSUMA,IWOJIMA,RJX7   POINT (130.27056 30.78472)
#
# [74179 rows x 19 columns]

# %%
geo_df = geo_df.set_crs('epsg:4326')

# %%
afg.plot()
# Out:
# <AxesSubplot:>

# %%
geo_df.plot()
# Out:
# <AxesSubplot:>

# %%
print(gdf.crs)
# Out:
# epsg:4326
