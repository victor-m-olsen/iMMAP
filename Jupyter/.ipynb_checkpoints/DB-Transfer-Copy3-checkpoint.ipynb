# %%
import geopandas as gpd
from sqlalchemy import create_engine
import psycopg2

# %%
table_name = 'afg_fldzonea_100k_ncia_v2_271cm_dissolve_multipolygon'
geometry_column = 'wkb_geometry' #wkb_geometry geom

# %% [markdown]
# ### Connect to local

# %%
# Local config
password = ''
db_connection_url = "postgresql://postgres:{}@localhost:5432/HSDC".format(password)
con = create_engine(db_connection_url)

# %%
# Server config
password_hsdc = ''
db_connection_url_hsdc = "postgresql://my_geonode:{}@3.76.200.124:5432/my_geonode_data".format(password_hsdc)
con_hsdc = create_engine(db_connection_url_hsdc)

# %%
# Open local table
local_table = gpd.GeoDataFrame.from_postgis('SELECT * from {}'.format(table_name), con, geometry_column)

# %%
# Save to hsdc
local_table.to_postgis('afg_fldzonea_100k_ncia_v2_271cm', con_hsdc) # , if_exists='replace'
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\earth2\lib\site-packages\geopandas\io\sql.py:38, in _get_conn(conn_or_engine)
#      37     with conn_or_engine.begin() as conn:
# ---> 38         yield conn
#      39 else:
#
# File ~\anaconda3\envs\earth2\lib\site-packages\geopandas\io\sql.py:445, in _write_postgis(gdf, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     443 with _get_conn(con) as connection:
# --> 445     gdf.to_sql(
#     446         name,
#     447         connection,
#     448         schema=schema_name,
#     449         if_exists=if_exists,
#     450         index=index,
#     451         index_label=index_label,
#     452         chunksize=chunksize,
#     453         dtype=dtype,
#     454         method=_psql_insert_copy,
#     455     )
#     457 return
#
# ...
