# %%
import geopandas as gpd
import pandas as pd
import os
import json

from sqlalchemy import create_engine
import psycopg2 # required for exporting to postgis

# %%
os.chdir(r'D:\iMMAP\proj\ASDC\data\settlement')
print(os.getcwd())
# Out:
# D:\iMMAP\proj\ASDC\data\settlement

# %%
# Load database configuration from file
with open(r'D:\iMMAP\code\db_config\hsdc_local_db_config.json', 'r') as f:
    config = json.load(f)

# Create database URL with credentials
db_url = f"postgresql://{config['username']}:{config['password']}@{config['host']}:{config['port']}/{config['database']}"

# Connect to the database
con = create_engine(db_url)

# %%
# Load the point shapefile
points = gpd.read_file(r'D:\iMMAP\data\Afghanistan\HSDC-Official\afg_pplp.shp')

# Load the polygon shapefiles
polygons = gpd.read_file(r'D:\iMMAP\data\Afghanistan\HSDC-Official\afg_admbnda_adm2.shp')

# %%
# View Point original attributes
point_cols_original = points.columns.tolist()
point_cols_original
# Out:
# ['OBJECTID',
#  'SOURCE',
#  'VIL_UID',
#  'CNTR_CODE',
#  'AFG_UID',
#  'LANGUAGE_',
#  'LANG_CODE',
#  'ELEVATION',
#  'LAT_Y',
#  'LON_X',
#  'Note',
#  'Edited_by',
#  'Name_EN',
#  'Type_Settl',
#  'DIST_CODE',
#  'DIST_NA_EN',
#  'PROV_NA_EN',
#  'PROV_CODE_',
#  'UNIT_TYPE',
#  'DIST_NA_DA',
#  'PROV_NA_DA',
#  'REG_UNAMA_',
#  'DIST_NA_PS',
#  'REG_UNAM_1',
#  'VUID_Area_',
#  'VUIDNear',
#  'VUID_Build',
#  'VUID_Popul',
#  'VUID_Pop_p',
#  'VUID',
#  'Name_Local',
#  'Name_Loc_1',
#  'Name_Alter',
#  'class_AS',
#  'geometry']

# %%
# List point attributes to drop
point_columns_to_drop = ['index_right',
    'VUID',
    'VUID_Pop_p',
    'VUID_Popul',
    'VUID_Build',
    'VUIDNear',
    'VUID_Area_',
    'REG_UNAM_1',
    'DIST_NA_PS',
    'REG_UNAMA_',
    'PROV_NA_DA',
    'DIST_NA_DA',
    'UNIT_TYPE',
    'PROV_CODE_',
    'PROV_NA_EN',
    'DIST_NA_EN',
    'DIST_CODE',
    'DIST_CODE',
    'Note',
    'AFG_UID']

# %%
# Filtere out attributes in Points
point_cols_keep = []

# Iterate over each element in list A
for element in point_cols_original:
    # Check if the element is not in list B
    if element not in point_columns_to_drop:
        # If the element is not in list B, add it to the new list
        point_cols_keep.append(element)
        
point_cols_keep
# Out:
# ['OBJECTID',
#  'SOURCE',
#  'VIL_UID',
#  'CNTR_CODE',
#  'LANGUAGE_',
#  'LANG_CODE',
#  'ELEVATION',
#  'LAT_Y',
#  'LON_X',
#  'Edited_by',
#  'Name_EN',
#  'Type_Settl',
#  'Name_Local',
#  'Name_Loc_1',
#  'Name_Alter',
#  'class_AS',
#  'geometry']

# %%
points_filtered = points[point_cols_keep]

# %%
# View Polygon original attributes
label_list = polygons.columns.tolist()
label_list
# Out:
# ['id',
#  'shape_leng',
#  'shape_area',
#  'adm2_en',
#  'adm2_da',
#  'adm2_pcode',
#  'adm2_ref',
#  'adm2alt1en',
#  'adm2alt2en',
#  'adm2alt1da',
#  'adm2alt2da',
#  'adm1_en',
#  'adm1_da',
#  'adm1_pcode',
#  'adm0_en',
#  'adm0_da',
#  'adm0_pcode',
#  'date',
#  'validon',
#  'validto',
#  'reg_en',
#  'reg_da',
#  'reg_pcode',
#  'geometry']

# %%
# Filter polygon attributes

strings_to_remove = [
 'id',
 'shape_leng',
 'shape_area',
 'adm2_ref',
 'adm2alt1en',
 'adm2alt2en',
 'adm2alt1da',
 'adm2alt2da',
 'date',
 'validon',
 'validto']

new_label_list = [x for x in label_list if x not in strings_to_remove]
print(new_label_list)
# Out:
# ['adm2_en', 'adm2_da', 'adm2_pcode', 'adm1_en', 'adm1_da', 'adm1_pcode', 'adm0_en', 'adm0_da', 'adm0_pcode', 'reg_en', 'reg_da', 'reg_pcode', 'geometry']

# %%
polygons_filtered = polygons[new_label_list]

#cities_with_country = cities.sjoin(countries, how="inner", predicate='intersects')
# Perform spatial join for between points and polygons
settlement_with_admin = points_filtered.sjoin(polygons_filtered, how='inner')

# %%
# New point attributes after joing
settlement_with_admin.columns.tolist()
# Out:
# ['OBJECTID',
#  'SOURCE',
#  'VIL_UID',
#  'CNTR_CODE',
#  'LANGUAGE_',
#  'LANG_CODE',
#  'ELEVATION',
#  'LAT_Y',
#  'LON_X',
#  'Edited_by',
#  'Name_EN',
#  'Type_Settl',
#  'Name_Local',
#  'Name_Loc_1',
#  'Name_Alter',
#  'class_AS',
#  'geometry',
#  'index_right',
#  'adm2_en',
#  'adm2_da',
#  'adm2_pcode',
#  'adm1_en',
#  'adm1_da',
#  'adm1_pcode',
#  'adm0_en',
#  'adm0_da',
#  'adm0_pcode',
#  'reg_en',
#  'reg_da',
#  'reg_pcode']

# %%
pd.set_option('display.max_columns', 500)
settlement_with_admin.iloc[:50]
# Out:
#       OBJECTID                SOURCE  VIL_UID  CNTR_CODE LANGUAGE_  LANG_CODE  \
# 0          1.0       Yale POP_MASTER  SBK-047        0.0    Pashto        2.0
# 1          2.0       Yale POP_MASTER  SBK-042        0.0      Dari        1.0
# 2          3.0       Yale POP_MASTER  SBK-011        0.0      Dari        1.0
# 3          4.0       Yale POP_MASTER  SBK-037        0.0      Dari        1.0
# 4          5.0  USAID AIDVillageView  SBK-005        0.0      Dari        1.0
# 5          6.0       Yale POP_MASTER  SBK-040        0.0      Dari        1.0
# 6          7.0  USAID AIDVillageView  SBK-004        0.0      Dari        1.0
# 7          8.0       Yale POP_MASTER  SBK-029        0.0    Pashto        2.0
# 8          9.0       Yale POP_MASTER  SBK-022        0.0      Dari        1.0
# 9         10.0  USAID AIDVillageView  SBK-002        0.0      Dari        1.0
# 10        11.0       Yale POP_MASTER  SBK-023        0.0      Dari        1.0
# 11        12.0       Yale POP_MASTER  SBK-046        0.0      Dari        1.0
# 12        13.0       Yale POP_MASTER  SBK-017        0.0    Pashto        2.0
# 13        14.0       Yale POP_MASTER  SBK-025        0.0      Dari        1.0
# 14        15.0       Yale POP_MASTER  SBK-008        0.0      Dari        1.0
# 15        16.0       Yale POP_MASTER  SBK-053        1.0      Dari        1.0
# 16        17.0       Yale POP_MASTER  SBK-041        0.0      Dari        1.0
# 17        18.0       Yale POP_MASTER  SBK-044        0.0      Dari        1.0
# 18        19.0       Yale POP_MASTER  SBK-009        0.0      Dari        1.0
# 19        20.0       Yale POP_MASTER  SBK-015        0.0      Dari        1.0
# 20        21.0       Yale POP_MASTER  SBK-010        0.0      Dari        1.0
# 21        22.0       Yale POP_MASTER  SBK-048        0.0      Dari        1.0
# 22        23.0       Yale POP_MASTER  SBK-049        0.0      Dari        1.0
# 23        24.0       Yale POP_MASTER  SBK-014        0.0      Dari        1.0
# 24        25.0       Yale POP_MASTER  SBK-028        0.0      Dari        1.0
# 25        26.0       Yale POP_MASTER  SBK-013        0.0    Pashto        2.0
# 26        27.0       Yale POP_MASTER  SBK-020        0.0      Dari        1.0
# 27        28.0       Yale POP_MASTER  SBK-019        0.0      Dari        1.0
# 28        29.0       Yale POP_MASTER  SBK-036        0.0      Dari        1.0
# 5039    5040.0       Yale POP_MASTER  QEK-051        0.0      Dari        1.0
# 5040    5041.0       Yale POP_MASTER  QEK-054        0.0      Dari        1.0
# 5046    5047.0       Yale POP_MASTER  QEK-046        0.0    Pashto        2.0
# 5050    5051.0       Yale POP_MASTER  QEK-045        0.0      Dari        1.0
# 5051    5052.0       Yale POP_MASTER  QEK-050        0.0      Dari        1.0
# 5055    5056.0  USAID AIDVillageView  QEK-008        0.0      Dari        1.0
# 5056    5057.0       Yale POP_MASTER  QEK-049        0.0      Dari        1.0
# 5060    5061.0       Yale POP_MASTER  QEK-058        0.0    Pashto        2.0
# 5064    5065.0       Yale POP_MASTER  QEK-063        0.0    Pashto        2.0
# 5067    5068.0       Yale POP_MASTER  QEK-052        0.0      Dari        1.0
# 5071    5072.0       Yale POP_MASTER  QEK-061        0.0      Dari        1.0
# 5072    5073.0       Yale POP_MASTER  QEK-062        0.0      Dari        1.0
# 5073    5074.0       Yale POP_MASTER  QEK-071        0.0      Dari        1.0
# 5179    5180.0       Yale POP_MASTER  SBK-021        0.0      Dari        1.0
# 5180    5181.0  USAID AIDVillageView  SBK-003        0.0      Dari        1.0
# 5181    5182.0       Yale POP_MASTER  SBK-024        0.0      Dari        1.0
# 5182    5183.0       Yale POP_MASTER  SBK-043        0.0    Pashto        2.0
# 5183    5184.0       Yale POP_MASTER  SBK-016        0.0      Dari        1.0
# 5184    5185.0       Yale POP_MASTER  SBK-045        0.0     Other        9.0
# 5186    5187.0       Yale POP_MASTER  SBK-012        0.0      Dari        1.0
# 5190    5191.0       Yale POP_MASTER  SBK-035        0.0    Pashto        2.0
#
#        ELEVATION      LAT_Y      LON_X                 Edited_by  \
# 0     547.452393  32.140700  61.444500                      None
# 1     559.284424  31.969100  61.693700                      None
# 2     514.669189  32.048600  61.255500                      None
# 3     519.916382  32.055300  61.283600                      None
# 4     517.794800  32.082500  61.211100                      None
# 5     527.208801  32.083100  61.294500                      None
# 6     539.976379  32.092300  61.415600                      None
# 7     531.174011  32.108200  61.346700                      None
# 8     540.074829  32.109300  61.412700                      None
# 9     537.434021  32.115400  61.383200                      None
# 10    531.803223  32.118000  61.348100                      None
# 11    545.062378  32.122100  61.438600                      None
# 12    550.969177  32.130300  61.485400                      None
# 13    568.161621  32.130700  61.616800                      None
# 14    575.499573  32.133200  61.692500                      None
# 5046                  Karaily             Other  POINT (61.77260 32.31620)
# 5050             Karez-e Alif             Other  POINT (61.72110 32.32250)
# 5051        Haji Taj Muhammad             Other  POINT (61.80290 32.32350)
# 5055  Karez-e Mulla Shahnowaz             Other  POINT (61.75940 32.32740)
# 5056       Koh-e Haji Surkhah             Other  POINT (61.68030 32.33010)
# 5060           Karez-e Naghak             Other  POINT (61.78210 32.33770)
# 5064                     Kota             Other  POINT (61.71710 32.34250)
# 5067                  Karaily             Other  POINT (61.81130 32.34390)
# 5071     Qal`ah-ye Karash Now             Other  POINT (61.75600 32.35340)
# 5072                Sar Dasht             Other  POINT (61.78370 32.35370)
# 5073          Muhammad Hashim             Other  POINT (61.70850 32.35700)
# 5179              Sahib Zadah             Other  POINT (61.79070 32.17340)
# 5180  Howzak-e Muhammad-Aslam             Other  POINT (61.75300 32.17440)
# 5181                     Zaye             Other  POINT (61.83120 32.18250)
# 5182        Landi Karez Kelay             Other  POINT (61.65840 32.18260)
# 5183                     Jowi             Other  POINT (61.85630 32.18730)
# 5184                     Jowi             Other  POINT (61.82620 32.18810)
# 5186                  Dewalak             Other  POINT (61.89700 32.19370)
# 5190     Karez-e Mulla Jum`ah             Other  POINT (61.65760 32.20020)
#
#       index_right  adm2_en  adm2_da adm2_pcode adm1_en adm1_da adm1_pcode  \
# 0             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 1             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 2             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 3             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 4             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 6             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 7             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 8             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 9             192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 10            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 11            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 12            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 13            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 14            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 15            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 16            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 17            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 18            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 19            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 20            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 21            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 22            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 23            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 24            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 25            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 26            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 27            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 28            192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5039          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5040          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5046          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5050          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5051          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5055          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5056          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5060          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5064          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5067          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5071          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5072          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5073          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5179          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5180          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5181          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5182          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5183          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5184          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5186          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
# 5190          192  Shibkoh  شیب کوه     AF3305   Farah    فراه       AF33
#
#           adm0_en    adm0_da adm0_pcode   reg_en        reg_da reg_pcode
# 0     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 1     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 2     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 3     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 4     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 6     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 7     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 8     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 9     Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 10    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 11    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 12    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 13    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 14    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 15    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 16    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 17    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 18    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 19    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 20    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 21    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 22    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 23    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 24    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 25    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 26    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 27    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 28    Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5039  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5040  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5046  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5050  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5051  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5055  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5056  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5060  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5064  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5067  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5071  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5072  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5073  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5179  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5180  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5181  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5182  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5183  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5184  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5186  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR
# 5190  Afghanistan  افغانستان         AF  Western  لویدیځه حوزه        WR

# %%
settlement_with_admin['class_AS'].unique()
# Out:
# array(['Sub', 'Other', 'District Capital', 'Province Capital', 'Capital'],
#       dtype=object)

# %%
# Save the result to a new shapefile
settlement_with_admin.to_file('points_with_attributes2.shp')
# Out:
# C:\Users\VMO\AppData\Local\Temp\ipykernel_12784\310569772.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   settlement_with_admin.to_file('points_with_attributes2.shp')

# %%
settlement_with_admin.to_postgis('afg_pplp', con, if_exists='replace')

# %%
new_sett = gpd.read_file("D:\iMMAP\proj\ASDC\data\settlement\points_with_attributes2.shp")
original_sett = points_filtered

# %%
len(new_sett.columns.tolist())
# Out:
# 30

# %%
len(original_sett.columns.tolist())
# Out:
# 17
